# %% [markdown]
# #**Session Flow:**

# %% [markdown]
# 👨🏻‍🎓 Learning Objective:
#
# * Introduction
# * Theme
# * Primary Goals
#
# **1️⃣ Understanding Recursion: Introduction and Basics**
# * What is recursion and how it works
# * The process of solving problems recursively
# *  The importance of defining a base case
# *  Advantages and power of recursion
# * Watching out for stack overflow errors
#
# 2️⃣ Recursive Function Design
#
# * Defining recursive functions
# * Breaking down problems into smaller subproblems
# * Examples of recursive function design
# * Activity: Guess the Word
#
# 3️⃣ Implementing Recursion in Algorithms
# * Recursion in computer science algorithms
# * Examples of recursive algorithms (e.g., factorial, Fibonacci)
# * Recursive approaches for problem-solving
#
# 4️⃣ Analyzing Recursive Calls
# *  Understanding recursion depth
# * Tracking the number of recursive calls
# * Analyzing time complexity in recursive solutions
#
# 5️⃣ Best Practices and Optimization Techniques
# * Defining efficient base cases
# * Tail recursion and optimization
# * Memoization and dynamic programming
# * Activity: True or False
#
# 📝 Summary
#
# * What did we learn?
# * Shortcomings & Challenges
# * Best Practices & Tips
#
# 🔗 Enhance your Knowledge
#
# * Mnemonic
# * Additional Resources
#
# 🔍 Try it Yourself
#
# * Activities
# * Social Engagement

# %% [markdown]
# ##Here's a visualisation tool to help you out! ⭐⭐⭐

# %% [markdown]
# **CS Circles Visualize** is an online tool that allows users to visualize the execution of Python code step by step. It can be used to better understand how code works and identify errors in code, making it a valuable resource for learners of all levels.
#
# To use CS Circles Visualize, users simply need to input their Python code into the text editor and click the "Visualize Code" button. The tool will then display the code execution step by step, highlighting each line of code as it is executed and displaying the current value of variables. Users can also pause the execution at any point to inspect the current state of the program.
#
# CS Circles Visualize can be particularly useful for beginners who are just starting to learn Python or programming in general, as it can help them visualize the concepts they are learning in a more concrete way. However, it can also be used by more experienced programmers who want to better understand how their code works or troubleshoot errors.
#
# **Here's the [link](https://cscircles.cemc.uwaterloo.ca/visualize#mode=display) to the resource**

# %% [markdown]
# # **👨🏻‍🎓 Learning Objective 👨🏻‍🎓**

# %% [markdown]
# ##**Introduction**
#
# 👋 Hi there! Let's learn about recursion!
# 🔄 Recursion is a way of solving problems by breaking them down into smaller and smaller subproblems until they become simple enough to be solved directly.
# 🔁 The process of solving a problem recursively involves defining a function that calls itself with a modified version of the original input until a base case is reached.
# 🛑 The base case is the simplest possible version of the problem, where the function can return a known value without making more recursive calls.
# 👍 Recursion can be a powerful tool for solving complex problems, but it's important to keep track of how many recursive calls are being made, as too many can lead to stack overflow errors.
# 🤔 So, remember always to define a base case and check that the problem is broken down into simpler subproblems in each recursive call.
# 💻 With these fundamentals in mind, you can start exploring how to apply recursion to various problems in computer science and beyond!
#
#
#
# **Focus- Recursion fundamentals, Recursive function structure, base case, recursive case**
#
# **Pre-requisites- Data Structure Fundamentals**
#
# ##**Theme**
#
#
# Recursion is important in programming due to its ability to solve complex problems by breaking them down into simpler subproblems. It follows the divide-and-conquer strategy, enabling efficient and optimized solutions. Recursive functions offer code reusability and can be more concise, making the code easier to understand. Recursion plays a vital role in tree and graph traversal algorithms, dynamic programming, and backtracking. It is widely used in mathematical recurrences and aligns well with functional programming. Although recursion provides elegant solutions, developers should be mindful of potential stack overflow errors and consider iterative approaches when needed. Understanding recursion's concepts and managing base cases are crucial for effectively using recursion in programming tasks.
#
#
#
#
#
# ##**Primary Goals**
#
# 1. Recursive vs. iterative approaches:
#   * 🔍 Understand the difference between recursion and iteration
#   * 🧐 Compare and contrast recursive and iterative solutions
#   * 🌟 Choose the appropriate approach for a given problem
# Anatomy of a recursive function:
# 2. 🧩 Understand the structure of a recursive function
#   * 👀 Trace the execution of a recursive function
#   * 📝 Write your own recursive functions
# 3. Base case and recursive case:
#   * 🎯 Understand the importance of base cases in recursive functions
#   * 🌟 Identify the base case and recursive case in a given function
#   * 👀 Trace the execution of a function with multiple recursive calls
# 4. Simple examples of recursion (e.g. factorial, Fibonacci sequence):
#   * 🌟 Apply recursion to simple mathematical problems
#   * 🤝 Collaborate with peers to solve recursive problems
#   * 💻 Practice implementing recursive functions in programming languages
# 5. Common pitfalls and how to avoid them:
#   * ⚠️ Identify common mistakes in recursive functions

# %% [markdown]
# # **📖 Learning Material 📖**

# %% [markdown]
# ##  **Introduction to Recursion**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 🔄 Recursion is when a function calls itself to solve a problem. In Python, it's used for breaking down a problem into smaller subproblems.
#
# 👉 When a function calls itself, it creates a new instance with its own variables. This helps work on smaller subsets of the problem and return a value to the original call when the base case is reached.
#
# ⚠️ Recursion is powerful but be careful to avoid infinite loops or stack overflow errors. A base case is needed to stop recursion. It's the simplest version of the problem that can be solved directly.
#
# 🌳 Recursion is used in algorithms with trees or linked structures, searching, sorting, and math problems like factorials and Fibonacci sequences.
#
# 💡 Once you understand it, recursion can be a powerful tool in your programming toolbox.

# %% [markdown]
# ##  **Recursive Vs Iterative Approach**

# %% [markdown]
# 🔄 Recursion and iteration are two different approaches to solving problems in programming.
#
# 👉 Iteration uses loops to repeat a set of instructions until a condition is met. It is often used when the number of repetitions is known or easily determined.
#
# Here's an example of an iterative function that calculates the factorial of a number:

# %%
def iterative_factorial(n):
    result = 1  # Initialize a variable named result with a value of 1
    for i in range(1, n+1):  # Loop through numbers from 1 to n (inclusive)
        result *= i  # Multiply the current value of result by the current number in the loop
        print(result)  # Print the current value of result
    return result  # Return the final value of result after the loop is finished

# %%
iterative_factorial(4)
# Out:
# 1
# 2
# 6
# 24
# 24

# %% [markdown]
# 🔄 Recursion, on the other hand, breaks down a problem into smaller subproblems and solves them recursively. It is often used when the problem can be expressed in terms of smaller subproblems of the same kind.
#
# Here's an example of a recursive function that calculates the factorial of a number:

# %%
def recursive_factorial(n):
    if n == 0:  # Base case: if n equals 0
        return 1  # Return 1 (as 0! equals 1)
    else:  # If n is not equal to 0
        # Recursively call the function with n-1 as the argument and multiply the result by n
        return n * recursive_factorial(n-1)

# %%
recursive_factorial(4)
# Out:
# 24

# %%
def custom_code(n):
  if n<=1:
    print(1)
  else:
    custom_code(n-1)
    print(n)


custom_code(5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def fibo(n):
  if n<=1:
    return n
  else:
    return fibo(n-1)+fibo(n-2)


n=7
fibo(n)
# Out:
# 1
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-0b75d5ea31ee> in <cell line: 9>()
#       7
#       8 n=7
# ----> 9 fibo(n)
#
# <ipython-input-10-0b75d5ea31ee> in fibo(n)
#       3     print(n)
#       4   else:
# ----> 5     fibo(n-1)+fibo(n-2)
#       6     print(n)
#       7
#
# <ipython-input-10-0b75d5ea31ee> in fibo(n)
#       3     print(n)
#       4   else:
# ----> 5     fibo(n-1)+fibo(n-2)
#       6     print(n)
#       7
#
# <ipython-input-10-0b75d5ea31ee> in fibo(n)
#       3     print(n)
#       4   else:
# ----> 5     fibo(n-1)+fibo(n-2)
#       6     print(n)
#       7
#
# <ipython-input-10-0b75d5ea31ee> in fibo(n)
#       3     print(n)
#       4   else:
# ----> 5     fibo(n-1)+fibo(n-2)
#       6     print(n)
#       7
#
# <ipython-input-10-0b75d5ea31ee> in fibo(n)
#       3     print(n)
#       4   else:
# ...

# %% [markdown]
# 👉 In this example, the base case is when n equals 0, at which point the function returns 1. Otherwise, it calls itself with a simpler version of the problem (n-1), until the base case is reached.
#
# 🔄 Recursion can be more elegant and concise than iteration, but it can also be less efficient and more memory-intensive. It's important to choose the right approach depending on the problem at hand.

# %% [markdown]
# ##**Anatomy of a Recursive Function- Base Case and Recursive Case**

# %% [markdown]
# Here's the anatomy of a recursive function:
#
# 👉 The **base case** is the simplest version of the problem that can be solved directly, without further recursion. It's the stopping condition that prevents the function from calling itself infinitely.

# %%
def recursive_function(parameter):
    if base_case:
        # Return value for the base case

    else:
        # Recursive case: call the function with a simpler version of the problem
        recursive_function(simpler_parameter)

# %% [markdown]
# 👉 The **recursive case** is the part of the function that calls itself with a simpler version of the problem. This is where the function breaks down the original problem into smaller subproblems and solves them recursively.

# %%
def recursive_factorial(n):  # Define a function that takes an integer n as input
    if n == 0:  # Base case: if n is 0, return 1
        return 1
    else:  # Recursive case: if n is not 0, call the function recursively with n-1 and multiply by n
        return n * recursive_factorial(n-1)

# Example usage:
print(recursive_factorial(0))  # Output: 1, because 0! = 1
print(recursive_factorial(5))  # Output: 120, because 5! = 5 * 4 * 3 * 2 * 1 = 120
print(recursive_factorial(10))  # Output: 3628800, because 10! = 10 * 9 * 8 * ... * 1 = 3628800
# Out:
# 1
# 120
# 3628800

# %% [markdown]
# 👉 The **function call stack** is a **data structure that stores the intermediate values of the function parameters and local variables as the function calls itself recursively**. Each recursive call adds a new frame to the call stack, and the frames are removed from the stack as the function returns values back to the original call.

# %%
# Example of a call stack for a recursive function
recursive_function(3)
    recursive_function(2)
        recursive_function(1)
            recursive_function(0)
                return 1
            return 1 * 1
        return 2 * 1
    return 3 * 2

# %% [markdown]
# 👉 The **termination condition** is the condition that stops the recursion from continuing indefinitely. This can be the base case or some other condition that is checked before each recursive call to ensure that the recursion terminates properly.

# %%
def recursive_fibonacci(n):
    if n <= 1:  # Base case: if n is less than or equal to 1
        return n  # Return n (i.e., 0 if n is 0, 1 if n is 1)
    else:  # If n is greater than 1
        # Recursively call the function with n-1 and n-2 as the arguments and add the results
        return recursive_fibonacci(n-1) + recursive_fibonacci(n-2)

# %% [markdown]
# In this example, the termination condition is n <= 1, which ensures that the function does not call itself with negative values of n, and that it eventually reaches the base case when n equals 0 or 1.

# %% [markdown]
# The anatomy of a recursive function involves a base case, a recursive case, a function call stack, and a termination condition. Understanding these components is essential for writing correct and efficient recursive functions.

# %% [markdown]
# ## 🔍 **Activity: Guess the Word**

# %% [markdown]
# **Riddle 1:**
#
# I'm a way to solve problems, step by step I go,
#
# A process of repetition, I clearly show.
#
# From start to end, I repeat my action,
#
# In the realm of problem-solving, I gain traction.
#
# What am I?
#
# **Riddle 2:**
#
# In a function, I call myself,
#
# A process of repetition, not to dispel.
#
# Deeper and deeper, I traverse my way,
#
# Recursion is my name, day by day.
#
# What am I?

# %% [markdown]
# ### **Answers:**

# %% [markdown]
# Answer 1:
# Iteration
#
# Explanation:
# In programming, iteration refers to the process of repeating a block of code or steps in a loop until a specific condition is met. It allows solving problems by repeatedly performing the same action, making it a fundamental concept in programming.
#
# Answer 2:
# Recursion
#
# Explanation:
# Recursion is a programming technique where a function calls itself to solve a problem by breaking it down into smaller instances of the same problem. It involves the process of solving a complex problem by solving smaller subproblems and gradually building up the solution.

# %% [markdown]
# ##**Recursion Examples**

# %% [markdown]
# **1. Factorial: Write a recursive function to compute the factorial of a given number. The factorial of n is defined as the product of all positive integers from 1 to n.**

# %%
def factorial(n):
    if n == 0:  # Base case: if n equals 0
        return 1  # Return 1 (as 0! equals 1)
    else:  # If n is not equal to 0
        # Recursively call the function with n-1 as the argument and multiply the result by n
        return n * factorial(n-1)

# Example usage
print(factorial(5))  # Output: 120 (as 5! equals 120)
# Out:
# 120

# %% [markdown]
# This code defines a function factorial that calculates the factorial of a given positive integer n using recursion. If n is 0, the function returns 1 (as 0! = 1). Otherwise, the function multiplies n by the factorial of n-1 (i.e., (n-1)!) to get the factorial of n. The example usage shows how to call the function to calculate the factorial of 5 (which is 120).

# %% [markdown]
# **2. Fibonacci sequence: Write a recursive function to compute the nth number in the Fibonacci sequence. The Fibonacci sequence is a sequence of numbers where each number is the sum of the two preceding ones, starting from 0 and 1.**

# %%
def fibonacci(n):
    if n <= 1:  # Base case: if n is less than or equal to 1
        return n  # Return n (i.e., 0 if n is 0, 1 if n is 1)
    else:  # If n is greater than 1
        # Recursively call the function with n-1 and n-2 as the arguments and add the results
        return fibonacci(n-1) + fibonacci(n-2)

# Example usage
print(fibonacci(7))  # Output: 13 (as the 7th Fibonacci number is 13)
# Out:
# 13

# %% [markdown]
# This code defines a function fibonacci that calculates the nth Fibonacci number using recursion. If n is 0 or 1, the function returns n (as the 0th and 1st Fibonacci numbers are 0 and 1, respectively). Otherwise, the function recursively calls itself with n-1 and n-2 as the arguments and adds the results to get the nth Fibonacci number. The example usage shows how to call the function to calculate the 7th Fibonacci number, which is 13.

# %% [markdown]
# **Both of these problems can also be solved iteratively, but recursive solutions are often more elegant and easier to read and understand. However, it's important to keep in mind that recursive solutions can be less efficient in terms of space usage, so for large inputs, an iterative solution may be preferable.**

# %% [markdown]
# ##**Space and Time Complexity of Recursive and Iterative approach**

# %% [markdown]
# **Iterative factorial function:**
#
# * Time complexity: O(n), where n is the input number.
# * Space complexity: O(1), because the function uses a constant amount of space to store the result and loop counter.
#
# **Recursive factorial function:**
#
# * Time complexity: O(n), where n is the input number.
# * Space complexity: O(n), because the function creates n function call frames on the call stack to store the intermediate values of the function parameters and local variables.
#
#
#
# As you can see, both functions have the same time complexity, but the recursive function has a higher space complexity due to the overhead of creating function call frames on the call stack. This means that for large values of n, the recursive function may run out of stack space and cause a stack overflow error, while the iterative function will continue to work without any issues.
#
# **In general, iterative functions tend to be more efficient in terms of space usage, while recursive functions tend to be more elegant and easier to read and understand. It's important to choose the right approach depending on the specific requirements and constraints of the problem at hand.**

# %% [markdown]
# ##**Some Common Pitfall around Recursion.** 💀💀💀

# %% [markdown]
# 🚫 Recursion is a powerful tool in programming, but it can be easy to fall into some common pitfalls. Here are some of the most common mistakes made when working with recursion, and how to avoid them:
#
# * 🕳️ **Infinite recursion:** This happens when a function calls itself indefinitely without ever reaching the base case. To avoid infinite recursion, make sure that your recursive function has a clear base case that will eventually be reached.
#
# * 🧱 **Redundant work:** Recursive functions can sometimes perform redundant calculations or operations. To avoid this, try to use memoization or dynamic programming techniques to store intermediate results and avoid repeating work.
#
# * 📈 **Stack overflow:** Recursive functions can use up a lot of memory if the function calls itself too many times. To avoid this, consider using an iterative approach or optimizing your recursive function to reduce the number of function calls.
#
# * 📝 **Poorly defined base case:** If the base case is not well-defined or does not handle all possible inputs, the function may produce unexpected results or errors. To avoid this, carefully consider all possible inputs and make sure that the base case covers all of them.
#
# * 🔀 **Infinite recursion on invalid input:** Recursive functions can sometimes run into infinite recursion if they are called with invalid input. To avoid this, add input validation checks at the beginning of your function to handle invalid inputs before the recursion begins.
#
# By keeping these common pitfalls in mind and carefully designing your recursive functions, you can avoid common errors and make the most of this powerful programming technique.

# %% [markdown]
# ## **Tips to Tame Recursion 💪💪**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Recursion can be a tricky concept to understand and work with, but there are a few ways to make it more comfortable for the user:
#
# **1. Start with simple examples**: Begin by using small, straightforward problems that can be solved with recursion. For example, calculating the factorial of a number or summing the elements of an array. This can help the user understand the basic structure of recursive functions before moving on to more complex problems.
#
# **2. Use clear and concise language**: When explaining recursion, try to use simple and easy-to-understand language. Avoid technical jargon and explain each step in plain terms.
#
# **3. Provide visual aids**: Visual aids such as diagrams, flowcharts, or animations can be helpful in illustrating the recursive process. Seeing the steps visually can make it easier for users to understand how recursion works.
#
# **4. Encourage practice**: Recursion can be challenging to understand at first, but with practice, it becomes more comfortable. Encourage users to write and test their recursive functions on small problems to build their confidence.
#
# **5. Use real-world examples**: Real-world examples can help make recursion more relatable and relevant to users. For example, explaining how a computer program uses recursion to search through a directory tree or how a maze-solving algorithm uses recursion to find a path.
#
# By following these tips, you can help make recursion more comfortable and accessible for users.

# %% [markdown]
# ## 🔍 **Activity: True/False**

# %% [markdown]
# 1. Recursion always consumes less memory compared to iteration. (True/False)
#
# 2. Recursion is more suitable than iteration for solving problems with a recursive mathematical or structural nature, such as tree traversal. (True/False)

# %% [markdown]
# ### **Answers:**

# %% [markdown]
# 1. False
#
# Explanation:
#
# Recursion can consume more memory compared to iteration due to the creation of multiple function call frames on the call stack for each recursive call. This can lead to stack overflow errors for deeply nested recursive calls. In contrast, iteration generally consumes less memory as it uses a single set of variables throughout the loop, without the overhead of function call frames.
#
# 2. True
#
# Explanation:
#
# True. Recursion is well-suited for solving problems with a recursive mathematical or structural nature, such as tree traversal, depth-first search, and problems that can be broken down into smaller instances of the same problem. Recursive algorithms can often provide elegant and concise solutions for such problems, making them a natural fit for tasks involving recursive patterns. However, it's essential to ensure that the recursive function has a proper base case to prevent infinite recursion.

# %% [markdown]
# # **✅ Summary ✅**

# %% [markdown]
# ##**What did you Learn?**
#
# * 🔍 Understand the difference between recursion and iteration. Recursion involves solving a problem by breaking it down into smaller subproblems of the same form, while iteration involves solving a problem by repeating a process.
# * 🧐 Compare and contrast recursive and iterative solutions - Recursive solutions can be elegant and concise but may have higher time complexity than iterative solutions. Iterative solutions may be less elegant but more efficient regarding time complexity.
# * 🌟 Choose the appropriate approach for a given problem - The appropriate approach depends on the problem at hand and the trade-offs between elegance and efficiency.
# * 🧩 Understand the structure of a recursive function - A recursive function has a base case and a recursive case. The base case is the terminating condition, while the recursive case is the condition that calls the function recursively.
# * 👀 Trace the execution of a recursive function - Tracing the execution of a recursive function involves following the function calls and returns on the call stack.
# * 📝 Write your own recursive functions - Writing a recursive function involves identifying the base case and recursive case and implementing the recursive call.
# * 🎯 Understand the importance of base cases in recursive functions - Base cases are necessary to prevent infinite recursion and ensure termination of the function.
# * 🌟 Identify the base case and recursive case in a given function - Identifying the base case and the recursive case is important for understanding the function's behavior and debugging.
# * 👀 Trace the execution of a function with multiple recursive calls - Tracing the execution of a function with multiple recursive calls involves following each call and returning on the call stack.
# * 🌟 Apply recursion to simple mathematical problems - Recursion can solve various mathematical problems, including the factorial function and the Fibonacci sequence.
#
# ###**Best Practices/Tips**
# * 🚀 Start with simple examples: Before diving into complex problems, start by understanding the basics of recursion with simple examples like calculating the factorial or printing a Fibonacci sequence.
# * 🌳 Trace your recursive calls: Use a tree diagram or a stack to visualize the recursive calls and understand how the function is executed. This will help you identify the base case and the recursive case.
# * 🚨 Define your base case carefully: A missing or incorrect base case can lead to infinite recursion, crashing your program. Be sure to define the base case carefully and test it thoroughly.
# * 💻 Test your functions: Testing is crucial in any programming project and especially important for recursive functions. Use test cases to ensure your function works correctly for various inputs.
# * 🤔 Simplify the problem: If you're struggling to solve a complex problem with recursion, try breaking it down into simpler sub-problems that can be solved recursively.
#
# ###**Shortcomings**
#
# * 🐢 **Slower execution**: Recursive functions can be slower than iterative solutions due to the overhead of function calls, leading to longer execution times for larger problems.
# * 🧐 **Harder to debug**: Recursive functions can be more challenging to debug than iterative solutions because of the complexity of the call stack. It can be tough to trace where the problem is occurring and which recursive call is causing it.
# * 🚨 **Risk of infinite recursion**: Incorrectly defined base cases or incorrect termination conditions can cause infinite recursion, which can crash your program.
# * 💻 **Stack overflow errors**: Recursive functions that call themselves too many times can cause stack overflow errors, which can crash your program.
# * 🤔 **Difficulty in understanding:** Recursion can be a challenging concept to understand, especially for beginners. Understanding how the function works and tracing the call stack can be difficult and time-consuming.
# * 🤝 **Collaborative challenges:** Working collaboratively on recursive functions can be challenging because understanding and tracing the call stack can be difficult, and it can be hard to identify which recursive calls are causing issues.
# * **🔍 Limited applicability:** Recursion is not always the best solution for every problem and may not be appropriate for some types of problems.

# %% [markdown]
# # **➕ Enhance your Knowledge ➕**

# %% [markdown]
# ###**Mnemonic**
#
#
# Once upon a time, there was a company called CodeDigital. They specialized in developing software applications using Python. They were facing a problem with one of their applications that required them to calculate the factorial of a number. The current implementation of the factorial function uses a loop, but the development team thought that it could be made more elegant and efficient using recursion.
#
# 🤔 The team decided to explore the concept of recursion and how it could be used to solve the problem.
#
# 🔍 They started by understanding the structure of a recursive function and how it differed from an iterative approach. They also learned about the base and recursive cases in a recursive function.
#
# 🌟 They decided to write their own recursive function to calculate the factorial of a number. They identified the base case as 1 and the recursive case as n * factorial(n-1).
#
# 🧐 They then compared the time complexity of the recursive function to the previous implementation using a loop. They found that the recursive function had a higher time complexity due to the overhead of the function calls.
#
# 👀 They traced the execution of the recursive function using a tree diagram and found that it made multiple calls to the function with decreasing values of n until it reached the base case.
#
# 💻 They then implemented the recursive function in their application and ran some tests to verify that it produced the correct results.
#
# 👨‍💻 However, they encountered a common pitfall in recursive functions - infinite recursion. They realized they had not defined the base case correctly and made the necessary changes to fix the function.
#
# 🌟 In the end, CodeDigital successfully used Python recursion fundamentals to improve their factorial function's efficiency and elegance. They were proud of their work and continued to explore new ways to use recursion in their applications.
#
# ##**Additional Reference Paper**
# https://www.datacamp.com/tutorial/understanding-recursive-functions-python

# %% [markdown]
# ##**Practice Problems**

# %% [markdown]
# ### **Write a program to find the factorial of a number using recursion.**

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)

# Taking input from user
num = int(input("Enter a number: "))

# Checking if the input is valid
if num < 0:
    print("Sorry, factorial does not exist for negative numbers")
elif num == 0:
    print("The factorial of 0 is 1")
else:
    print("The factorial of", num, "is", factorial(num))
# Out:
# Enter a number: 5
# The factorial of 5 is 120

# %% [markdown]
# ### **Write a program to find the sum of natural numbers up to n using recursion.**

# %%
def sum_natural_numbers(n):
    if n == 1:
        return 1
    else:
        return n + sum_natural_numbers(n-1)

# Taking input from user
num = int(input("Enter a number: "))

# Checking if the input is valid
if num <= 0:
    print("Invalid input. Please enter a positive integer.")
else:
    print("The sum of natural numbers up to", num, "is", sum_natural_numbers(num))
# Out:
# Enter a number: 33
# The sum of natural numbers up to 33 is 561

# %% [markdown]
# ### **Write a program to print the Fibonacci series up to n terms using recursion.**

# %%
def fibonacci(n):
    if n <= 1:
        return n
    else:
        return (fibonacci(n-1) + fibonacci(n-2))

# Taking input from user
num = int(input("Enter the number of terms: "))

# Checking if the input is valid
if num <= 0:
    print("Invalid input. Please enter a positive integer.")
else:
    print("Fibonacci series:")
    for i in range(num):
        print(fibonacci(i))
# Out:
# Enter the number of terms: 3
# Fibonacci series:
# 0
# 1
# 1

# %% [markdown]
# ### **medium Level**

# %% [markdown]
# ### **Write a program to find all possible permutations of a given string using recursion.**

# %%
def permutations(string, left, right):
    if left == right:
        print("".join(string))
    else:
        for i in range(left, right + 1):
            string[left], string[i] = string[i], string[left]
            permutations(string, left + 1, right)
            string[left], string[i] = string[i], string[left]

# Taking input from user
str = input("Enter a string: ")

# Calling the function
permutations(list(str), 0, len(str)-1)
# Out:
# Enter a string: aba
# aba
# aab
# baa
# baa
# aba
# aab

# %% [markdown]
# ### **Write a program to find the nth term in the Tribonacci sequence using recursion.**

# %%
def tribonacci(n):
    if n == 0 or n == 1:
        return 0
    elif n == 2:
        return 1
    else:
        return tribonacci(n-1) + tribonacci(n-2) + tribonacci(n-3)

# Taking input from user
num = int(input("Enter a number: "))

# Checking if the input is valid
if num < 0:
    print("Invalid input. Please enter a non-negative integer.")
else:
    print("The", num, "th term in the Tribonacci sequence is", tribonacci(num))
# Out:
# Enter a number: 7
# The 7 th term in the Tribonacci sequence is 13

# %% [markdown]
# ### **Write a program to find the sum of digits of a given number using recursion.**

# %%
def sum_of_digits(n):
    if n == 0:
        return 0
    else:
        return n%10 + sum_of_digits(n//10)

# Taking input from user
num = int(input("Enter a number: "))

# Checking if the input is valid
if num < 0:
    print("Invalid input. Please enter a non-negative integer.")
else:
    print("The sum of digits of", num, "is", sum_of_digits(num))
# Out:
# Enter a number: 1234
# The sum of digits of 1234 is 10

# %% [markdown]
# ### **Hard Level**

# %% [markdown]
# ### **Write a program to generate all possible permutations of a given string using recursion.**

# %%
def permutations(s):
    if len(s) == 0:
        return []
    elif len(s) == 1:
        return [s]
    else:
        result = []
        for i in range(len(s)):
            # Generating permutations of remaining string
            remaining = s[:i] + s[i+1:]
            perms = permutations(remaining)

            # Adding current character to each permutation
            for perm in perms:
                result.append(s[i] + perm)

        return result

# Taking input from user
s = input("Enter a string: ")

# Generating and printing all permutations
print("All possible permutations of", s, "are:")
print(permutations(s))
# Out:
# Enter a string: abc
# All possible permutations of abc are:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']

# %% [markdown]
# ### **Write a program to find the minimum number of steps required to convert one string into another using recursion.**

# %%
def min_steps(s1, s2, m, n):
    # If either of the strings is empty, return the length of the other string
    if m == 0:
        return n
    if n == 0:
        return m

    # If last characters of the strings are same, ignore them and find minimum steps for remaining strings
    if s1[m-1] == s2[n-1]:
        return min_steps(s1, s2, m-1, n-1)

    # If last characters of the strings are different, find minimum steps for all possible operations and return minimum of them
    return 1 + min(min_steps(s1, s2, m, n-1), # Insert
                   min_steps(s1, s2, m-1, n), # Remove
                   min_steps(s1, s2, m-1, n-1) # Replace
                   )

# Taking inputs from user
s1 = input("Enter first string: ")
s2 = input("Enter second string: ")

# Finding and printing minimum number of steps required to convert s1 to s2
print("Minimum number of steps required to convert", s1, "to", s2, "is:", min_steps(s1, s2, len(s1), len(s2)))
# Out:
# Enter first string: monday
# Enter second string: tuesday
# Minimum number of steps required to convert monday to tuesday is: 4

# %% [markdown]
# ### **Write a program to find the longest increasing subsequence of a given sequence using recursion.**

# %%
def longest_increasing_subsequence(seq, i, n, last):
    if i == n:
        return 0
    else:
        # If current element is greater than last element, include it in the subsequence
        if seq[i] > last:
            return max(1 + longest_increasing_subsequence(seq, i+1, n, seq[i]), # Include current element
                       longest_increasing_subsequence(seq, i+1, n, last) # Exclude current element
                       )
        else:
            # If current element is less than or equal to last element, exclude it from the subsequence
            return longest_increasing_subsequence(seq, i+1, n, last)

# Taking input from user
seq = list(map(int, input("Enter a sequence of integers: ").split()))

# Finding and printing longest increasing subsequence
print("Longest increasing subsequence is of length", longest_increasing_subsequence(seq, 0, len(seq), float('-inf')))
# Out:
# Enter a sequence of integers: 5 2 8 6 3 6 9 7
# Longest increasing subsequence is of length 4

# %% [markdown]
# # **Try it Yourself 📃**
#
# Are you ready to put your coding skills to the test and gain practical knowledge? We have some exciting coding questions waiting for you to solve! 🚀
#
# Your task is to attempt the coding questions associated with this lesson. These challenges have been thoughtfully designed to reinforce your understanding of the concepts covered in the course. You can find them in your dashboard under this lesson.
#
# Don't be shy! Share your findings, experiences, and any insights you gained while tackling these coding questions on the AlmaBetter community platform. Engage in discussions, help each other out, and celebrate your victories together!
#
# Remember, coding is not just about learning theory; it's about applying that knowledge to solve real-world problems. So, dive in, experiment, and have fun while honing your coding skills!
# Let's learn, grow, and inspire each other as a vibrant community of passionate learners. Happy coding! 💻 😊

# %% [markdown]
# ## **Task 1:**

# %% [markdown]
# ###**Activity 1:**

# %% [markdown]
# Write a recursive function that takes in a positive integer n and prints all numbers from 1 to n. 💻 Your function should take in one argument, n, and should print each number on a new line, starting from 1 and ending with n. 🤖 You should use recursion to solve this problem. 🚫 Your function should not use any loops, and should not use any built-in Python functions that solve the problem directly. 🔝 The function should handle all positive integer inputs, and should be as efficient as possible. Good luck! 🍀

# %%
# Your Code Here
def custom(n):
  if n<=1:
    print(n)
  else:
    custom(n-1)
    print(n)

custom(5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def countdown(n):
    if n == 0:
        print("Blastoff!")
    else:
        print(n)
        countdown(n-1)

countdown(4)
# Out:
# 4
# 3
# 2
# 1
# Blastoff!

# %% [markdown]
# ###**Activity 2:**

# %% [markdown]
# 🎮 You are designing a video game where players need to collect items to gain points.
#
# 💰 The points earned by a player depend on the number of items they have collected.
#
# 👨‍👧‍👦 You need to write a Python function that takes the number of items collected by a player as input and calculates the total points earned using recursion.
#
# 🔢 The total points earned are equal to the sum of natural numbers up to the number of items collected.
#
# 🏆 Your goal is to help players earn as many points as possible! Write a function calculate_points(items) that takes a single integer parameter items and returns the total points earned as an integer.

# %%
# Your code here
def calculate_points(items):
  if items==1:
    return 1
  else:
    return items+calculate_points(items-1)

calculate_points(5)
# Out:
# 15

# %% [markdown]
# ###**Activity 3:**

# %% [markdown]
# Imagine you are a math teacher explaining sequences to your class. You want to introduce a new sequence that is similar to the Fibonacci sequence, but with a twist! You tell your students about the Tribonacci sequence.
#
# 🔢 The Tribonacci sequence is a sequence of numbers where each term is the sum of the three preceding terms. The first three terms in the sequence are 0, 1, and 1, and the sequence continues as follows: 0, 0, 1, 1, 2, 4, 7, 13, 24, 44, 81.......
#
# Now write a program using recursion which would return the nth term in the tribonacci series.

# %%
# Your Code Here
def tribonaucci(n):
  if n==0 or n==1 or n==2:
    return 0
  elif n==3:
    return 1
  else:
    return tribonaucci(n-1)+tribonaucci(n-2)+tribonaucci(n-3)


tribonaucci(6)
# Out:
# 4

# %% [markdown]
# ### **Space and Time Complexity**

# %% [markdown]
# The time complexity of this recursive function is exponential, specifically **O(3^n)**, since it makes three recursive calls for every call except for the base cases.
#
# As for the space complexity, it is also exponential because the function makes a recursive call for every previous value of n, leading to a large number of function calls and an exponential growth in the call stack size. Specifically, the space complexity is **O(n)** due to the depth of the call stack.
#
# Therefore, this implementation is not suitable for large values of n, as it would require an enormous amount of time and memory.

# %% [markdown]
# ###**Activity 4:**

# %% [markdown]
# Sarah is a reading enthusiast and she just came about a concept caleed **Palindrome**. These are the words which reads the same in reverse. Eg: radar, level, madam etc.
#
#  She wants to write a program that uses recursion to check if the word formed by her friends is a palindrome or not. Can you help Sarah by writing a program that uses recursion to check if a given string is a palindrome or not?
#
# 🔠🔄🧑‍💻

# %%
# Your Code Here
def is_palin(string):
  if len(string)<2:
    return True
  elif string[0]!=string[-1]:
    return False
  else:
    return is_palin(string[1:-1])


is_palin("level")
# Out:
# True

# %% [markdown]
# ## **Task 2:**

# %% [markdown]
# ####**🔵 Share your approach of solving the challenge 3 and finding the time & space complexity of your code in the AlmaBetter Community Platform.**
