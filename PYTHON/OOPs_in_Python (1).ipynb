# %% [markdown]
# ## **Session Flow:**
#
# Learning Objective 👨🏻‍🎓
#
# * Introduction
# * Theme
# * Primary Goals
#
# Introduction to Object-Oriented Programming (OOPs) 📚🎯
#
# - Understand the basic principles of OOPs.
# - Explore the advantages and key concepts of OOPs.
#
# Creating and Working with Classes 🏗️🧱
#
# - Understand the concept of a class and its role in OOPs.
# - Learn how to create a class in Python.
# - Define attributes and methods within a class.
#
# Understanding Objects and Instances 🧬🔍
#
# - Understand the concept of objects and instances in OOPs.
# - Learn how to create instances of a class and their significance.
# * Activity 1
#
# Working with Attributes 🎛️🔧
#
# - Explore the concept of attributes in OOPs.
# - Learn how to define and manipulate attributes within a class.
#
# Utilizing Methods in Classes 📋🛠️
#
# - Understand the concept of methods in OOPs.
# - Learn how to define and use methods within a class to perform actions.
# Activity 2
#
# Embracing Polymorphism 🌈🦄
#
# - Understand the concept of polymorphism in OOPs.
# - Learn how to use polymorphism to write code that works with objects of different classes.
#
# Leveraging Inheritance 🧬🏗️
#
# - Understand the concept of inheritance and its role in OOPs.
# - Learn how to create a subclass that inherits properties and methods from its parent class.
# * Activity 3
#
#
# Practical Hands-On Projects 🤝🔨
#
# - Apply the knowledge gained to create real-world projects using OOPs in Python.
#
# 📝 Summary
#
# * What did we learn?
# * Shortcomings & Challenges
# * Best Practices & Tips
#
# 🔗 Enhance your Knowledge
#
# * Mnemonic
# * Additional Resources
#
# 🔍 Try it Yourself
#
# * Activities
# * Social Engagement

# %% [markdown]
# # **👨🏻‍🎓 Learning Objective 👨🏻‍🎓**

# %% [markdown]
# ##**Introduction**
#
# 🐍🔎 OOPs (Object-Oriented Programming) is a programming paradigm that is based on the concept of objects. An object is an instance of a class, which encapsulates data and functionality. In Python, everything is an object, and therefore, Python is an object-oriented language.
#
# Today, we will explore these concepts in detail enabling you to come up with more efficient codes.
#
# * Focus: Class, methods, objects, attribute, inheritance, polymorphism
#
# ## **🎯 Theme:**
#
# Beyond the Syntax: Step into the mystical world of Object-Oriented Programming (OOP), where code comes alive with enchantment!
# Cracking the OOP Code: Unravel the secrets of classes, objects, and the pillars of OOP!
# Weaving the OOP Tapestry: Thread by thread, craft your code's destiny with inheritance and polymorphism!
# The Art of Abstraction: Embrace the wizardry of encapsulation, shielding the mysteries of your objects!
# The Power of Inheritance: Discover the heirloom of code reusability, passing down knowledge through generations!
# Unraveling Polymorphic Wonders: Witness the shape-shifting prowess of polymorphism, where objects transcend boundaries!
#
# ##**Primary Goals**
#
# 1. Understand the basic principles of OOPs.
# 2. Understand the concept of a class and how to create a class in Python.
# 3. Understand the concept of objects and how to create an instance of a class.
# 4. Understand the concept of attributes and how to define and manipulate them.
# 5. Understand the concept of methods and how to define and use them in a class.
# 7. Understand the concept of inheritance and how to create a subclass that inherits properties and methods from its parent class.
# 8. Understand the concept of polymorphism and how to use it to write code that works with objects of different classes.
# 9. Understand the importance of good OOPs design and how to apply best practices when writing object-oriented code in Python.

# %% [markdown]
# # **📖 Learning Material 📖**

# %% [markdown]
# 👋 Hey there!
#
# 👨‍🏫 Today's lesson is all about Object Oriented Programming (OOPs).
#
# OOPs tends to be one of the most interesting concepts to learn in Python.
#
# So, let us understand what really Object Oriented Programming is.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Object-Oriented Programming  is a programming paradigm that revolves around the concept of objects, which can contain data and code to manipulate that data. In OOPs, programs are organized around objects, which can communicate with each other to perform tasks. OOPs is used to create reusable code, improve the code's readability and maintainability, and increase the program's modularity and scalability.
#
# Think of objects as real-world entities that have attributes and behaviors. For example, a car is an object that has attributes like make, model, and color, and behaviors like accelerating, braking, and turning.
#
# Similarly, in OOPs, we define classes that represent real-world entities. These classes have attributes and methods that define the characteristics and behaviors of the objects created from them.
#
# For example, consider a class called Car. This class can have attributes like make, model, and color, and methods like accelerate(), brake(), and turn(). When we create an object of this class, say a Toyota Camry, we can set its attributes to make='Toyota', model='Camry', and color='Red'. We can then call its methods, such as accelerate() to make it go faster, or brake() to slow it down.For this lesson we will construct our knowledge of OOPs in Python by building on the various topics.
#
# ---

# %% [markdown]
# **The main concept of OOPs is to bind the data and the functions that work on that together as a single unit.**
#
#
#
#
# Let us go through each of topic to understand the concept of Object Oriented Programming...

# %% [markdown]
# ## **Class**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In Python, a class is a blueprint for creating objects. It defines a set of attributes and methods that objects of that class will have. A class can be thought of as a template or a blueprint, and an object can be thought of as an instance of that class.
#
# To define a class in Python, we use the class keyword followed by the name of the class. Here's an example:
#
# ```
# class MyClass:
#     # Class Variables
#     variable1 = "Hello"
#     variable2 = "World"
#
#     # Class Method
#     def myMethod(self):
#         print("MyClass method called.")
#
# # Creating Object of MyClass
# myObject = MyClass()
#
# # Accessing Variables
# print(myObject.variable1)
# print(myObject.variable2)
#
# # Accessing Methods
# myObject.myMethod()
#
# ```
# In this example, we define a class called MyClass. This class has two class variables (variable1 and variable2) and a class method (myMethod). We then create an object of this class called myObject and use it to access the class variables and method.
#
# Note that in Python, the self parameter is used to refer to the current instance of the class. This parameter is automatically passed to instance methods, and you should include it as the first parameter of any method you define in a class.
#
# We will discover these features soon enough.
#
# ---

# %% [markdown]
# ## **Attributes**

# %% [markdown]
# Attributes are variables that hold information about an object. In Python, attributes are defined inside the class definition.
#
# Here's an example:
# ```
# class Person:
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
# ```

# %% [markdown]
# In this example, we've defined a class called Person with two attributes: name and age.
#
#  We've also defined a constructor method called __ ___init_____() that takes two arguments, name and age. Inside the constructor, we use the self keyword to refer to the object being created and set the name and age attributes to the corresponding arguments.
#
# We can now create an object of the Person class and set its attributes:

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

person = Person("John", 30)
print(person.name)
print(person.age)
# Out:
# John
# 30

# %% [markdown]
# As you can see, we've created an object of the Person class called person and set its name attribute to "John" and its age attribute to 30. We can access these attributes using dot notation (object.attribute).
#
# ---

# %% [markdown]
# ## **Objects**

# %% [markdown]
# An object is an instance of a class. We create objects by calling the class as if it were a function, passing in any necessary arguments. Here's an example:
# ```
# person = Person()
# ```
# In this example, we've created an object of the Person class called person. This object doesn't have any attributes or methods yet because we haven't defined them in the class.
#
# ---

# %% [markdown]
# ![oopoo.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##**Activity 1:**

# %% [markdown]
# ### **Answer the following questions**

# %%
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.is_engine_on = False

    def start_engine(self):
        self.is_engine_on = True

    def stop_engine(self):
        self.is_engine_on = False

    def display_info(self):
        print(f"Make: {self.make}")
        print(f"Model: {self.model}")
        print(f"Year: {self.year}")
        print(f"Engine Status: {'On' if self.is_engine_on else 'Off'}")

# Creating objects (instances) of the Car class
car1 = Car("Toyota", "Corolla", 2022)
car2 = Car("Honda", "Civic", 2023)

# Example of using attributes and methods
car1.start_engine()
car1.display_info()
car2.display_info()

# %% [markdown]
# **Question 1:**
# In the given Python code, what does the class Car represent?
#
# **Question 2:**
# What are the attributes defined in the Car class?
#
# **Question 3:**
# What is the purpose of the __init__ method in the Car class?
#
# **Question 4:**
# What does the method start_engine do?
#
# **Question 5:**
# How can we create multiple instances (objects) of the Car class with different make, model, and year?
#
# **Question 6:**
# What is the significance of the self keyword used in the methods of the Car class?

# %% [markdown]
# ### **Answers**

# %% [markdown]
# **1:**
# The class Car represents a blueprint or template for creating car objects. It defines the common properties (**attributes**) and behaviors (**methods**) that all car objects will have.
#
# **2:**
# The attributes defined in the Car class are **make, model, year, and is_engine_on.**
#
# **3:**
# The __init__ method is a special method called the **constructor**. It is automatically executed when a new instance of the Car class is created. It initializes the attributes of the object with the provided values.
#
# **4:**
# The method start_engine **sets the attribute is_engine_on to True**, indicating that the car's engine is turned on.
#
# **5:**
# We can create multiple instances of the Car class **by calling the class and passing different values for the make, model, and year attributes.** For example, car1 = Car("Toyota", "Corolla", 2022) and car2 = Car("Honda", "Civic", 2023) create two instances of the Car class with different attributes.
#
# **6:**
# The self keyword refers to the **instance of the class** itself. It allows the methods of the class to access and modify the attributes specific to that instance. When calling a method of a class, Python automatically passes the instance as the first argument (self), allowing the method to work with the object's data.

# %% [markdown]
# ## **Methods**

# %% [markdown]
# Methods are functions that are defined inside a class and can be called on objects of that class. They are used to perform operations on the attributes of the object or to return information about the object.
#
# Here's an example:

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print("Hello, my name is", self.name)

# %% [markdown]
# In this example, we've defined a class called Person with a method called greet(). The method takes no arguments and prints a greeting message that includes the object's name attribute. We can now call the greet() method on an object of the Person class:

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print("Hello, my name is", self.name)
person = Person("John", 30)
person.greet()
# Out:
# Hello, my name is John

# %% [markdown]
# As you can see, we've created an object of the Person class called person and called its greet() method, which prints the greeting.
#
# ---

# %% [markdown]
# ## **Let us practice hands-on coding question**

# %% [markdown]
# ###**Calculator for a Math Tutor** 🧑‍🏫
#
# You are a math tutor who needs a calculator to help your students with their homework. You decide to create a calculator class that can perform basic arithmetic operations to assist with solving problems. Your calculator should be able to add, subtract, multiply, and divide numbers, and it should be able to handle any errors such as dividing by zero. Additionally, you want to be able to clear the calculator to start fresh with a new problem.
#
# To implement this, you create a Calculator class that has methods for each of the basic arithmetic operations (add, subtract, multiply, divide) as well as a clear method. The class stores a result attribute that holds the current result of the calculator operations. Students can use this calculator to help them with their math problems, and you can use it to double-check their answers.

# %%
class Calculator:
    # Define the constructor method to initialize the class and set the initial result to 0
    def __init__(self):
        self.result = 0

    # Define a method to add num1 to num2 and store the result
    def add(self, num1, num2):
        self.result = num1 + num2
        return self.result

    # Define a method to subtract num2 from num1 and store the result
    def subtract(self, num1, num2):
        self.result = num1 - num2
        return self.result

    # Define a method to multiply num1 by num2 and store the result
    def multiply(self, num1, num2):
        self.result = num1 * num2
        return self.result

    # Define a method to divide num1 by num2 and store the result. Raise a ValueError if dividing by 0.
    def divide(self, num1, num2):
        if num2 == 0:
            raise ValueError("Cannot divide by zero.")
        self.result = num1 / num2
        return self.result

    # Define a method to clear the result back to 0
    def clear(self):
        self.result = 0
        return self.result

# %% [markdown]
# In this example, we define a class called Calculator. The __init__ method initializes the **result** attribute to 0. The class has four methods for performing basic arithmetic operations: **add, subtract, multiply, and divide**. Each method takes a single argument num, which is the number to perform the operation with. The divide method checks for a divide by zero error and raises a ValueError if the input is zero.
#
# The class also has a **clear** method that sets the **result** attribute to 0, effectively resetting the calculator.

# %% [markdown]
# Let's try out few of these methods

# %%
calc=Calculator()
#calling add method
addition=calc.add(42,6)

#calling subtract method
subtraction=calc.subtract(42,6)

#calling divide method
division=calc.divide(42,6)

#calling multiply method
mulitplication=calc.multiply(42,6)

print("Addition- ",addition)
print("subtraction- ",subtraction)
print("division- ",division)
print("mulitplication- ",mulitplication)
# Out:
# Addition-  48
# subtraction-  36
# division-  7.0
# mulitplication-  252

# %% [markdown]
# ### **Virtual Pet** 🐾
#
# You have been asked to develop a virtual pet program that simulates the experience of owning a pet. The program should allow users to create a new pet, feed it, play with it, and monitor its health. Each pet should have a name, age, and initial health level.
#
# To implement this program, you decide to create a class called Pet that represents a virtual pet. The Pet class has attributes for the pet's name, age, and health level. It also has methods for feeding the pet, playing with the pet, and checking the pet's health.

# %%
class Pet:
    # Define the constructor method to initialize the class with name, age and health_level
    def __init__(self, name, age, energy_level):
        self.name = name
        self.age = age
        self.energy_level = energy_level

    # Define a method to increase health level when feeding the pet
    def feed(self):
        self.energy_level += 10

    # Define a method to decrease health level when playing with the pet
    def play(self):
        self.energy_level -= 5

    # Define a method to check the health of the pet and print a message based on its health level
    def check_health(self):
        if self.energy_level < 50:
            print("Your pet is not feeling well.")
        else:
            print("Your pet is healthy.")

# %% [markdown]
# In this example, we define a class called **Pet**. The __init__ method initializes the pet's name, age, and health_level attributes. The class has three methods for interacting with the pet: **feed, play, and check_health**. The **feed** method increases the pet's health level by 10, while the **play** method decreases the health level by 5. The **check_health** method checks the pet's current health level and prints a message indicating whether the pet is healthy or not.

# %% [markdown]
# **Create an object of Pet class and demonstrate the usage of it's methods**

# %%
# Creating Object of Pet Class
my_pet = Pet("Fluffy", 2, 50)

# Feeding Pet
my_pet.feed()

# Playing with Pet
my_pet.play()

# Checking Pet Health
my_pet.check_health()

# Printing Pet Info
print("Name:", my_pet.name)
print("Age:", my_pet.age)
print("Energy Level:", my_pet.energy_level)
# Out:
# Your pet is healthy.
# Name: Fluffy
# Age: 2
# Energy Level: 55

# %% [markdown]
# ##**Activity 2:**

# %% [markdown]
# ### **True or False**

# %% [markdown]
# **Statement 1:**
# In Python, a method is a function defined within a class and operates on attributes specific to that class.
#
# **Statement 2:**
# Methods can be called directly on a class without creating an instance of the class.
#
# **Statement 3:**
# A method can access and modify the attributes of a class using the self keyword.
#
# **Statement 4:**
# Methods can have parameters, allowing them to accept input data for processing.
#
# **Statement 5:**
# The __init__ method in a class is automatically called when a new instance of the class is created.
#
# **Statement 6:**
# Python provides a built-in classmethod decorator to define class methods that operate on the class itself, rather than instances.

# %% [markdown]
# #### **Answers**

# %% [markdown]
# 1. True
#
#   A method in Python is a function defined within a class, and it can access and operate on the attributes specific to that class.
#
# 2. False
#
#   Methods need to be called on instances of a class, not directly on the class itself. They operate on the data associated with the particular instance.
#
# 3. True
#
#   Methods use the self keyword to access and modify attributes of the class. self refers to the instance of the class on which the method is called.
#
# 4. True
#
#   Methods can have parameters just like regular functions, allowing them to accept input data for processing within the class.
#
# 5. True
#
#   The __init__ method is a special method known as the constructor. It is automatically called when a new instance of the class is created, allowing you to set up the initial state of the object.
#
# 6. True
#
#   Python provides a built-in classmethod decorator to define class methods that operate on the class itself, rather than on instances. Class methods receive the class as their first argument (conventionally named cls) instead of self.

# %% [markdown]
# ## **🧘Relax 🧘**
#
# 🎓👨‍🎓👩‍🎓 Remember, mastering the concept of classes takes time, but don't worry! 💪🏼 If you've understood classes, methods, objects, and attributes, you're already 90% of the way there! 🙌🏼
#
# 🧐 However, polymorphism and inheritance can be a bit more challenging to grasp. Don't get discouraged if you don't understand them right away! 🤔 It's completely normal, and it may take some time to truly master these concepts.
#
# 🤓 Just remember that you can always go back and review the material, ask for help, or try some practice exercises. 📚👨‍🏫 You got this! 🚀

# %% [markdown]
# ## **Polymorphism**

# %% [markdown]
# Polymorphism is a core concept in object-oriented programming, which allows objects of different classes to be treated as if they are objects of the same class. This means that different objects can respond to the same message or method in different ways, depending on their individual implementation of that method.

# %% [markdown]
# For example, consider a program that models different types of animals. We can define a base class called Animal with a method called make_sound(), which simply prints the sound that the animal makes.

# %%
class Animal:
    def make_sound(self):
        print("Unknown sound")

# %% [markdown]
# We can then define two subclasses of Animal: Dog and Cat. Both of these subclasses inherit the make_sound() method from the Animal class, but they provide their own implementation of this method.

# %%
class Dog(Animal):
    def make_sound(self):
        print("Bark")

class Cat(Animal):
    def make_sound(self):
        print("Meow")

# %% [markdown]
# Now, we can create instances of both the Dog and Cat classes and call their make_sound() methods. Even though both of these methods have the same name, they produce different outputs, depending on the type of animal.

# %%
dog = Dog()
cat = Cat()
goat = Animal()
dog.make_sound()
cat.make_sound()
goat.make_sound()
# Out:
# Bark
# Meow
# Unknown sound

# %% [markdown]
# ![poly.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# This is an example of polymorphism, as we are able to treat objects of different classes (Dog and Cat) as if they are objects of the same class (Animal). This allows us to write more flexible and reusable code, as we can create generic functions that operate on any object that has a make_sound() method, regardless of its specific type.
#
# ---

# %% [markdown]
# ## **Let us practice hands-on coding question**

# %% [markdown]
# ####**Shape Calculator 📐**
#
# You are building a shape calculator program that allows users to calculate the area of various shapes, including squares, rectangles, and circles. Each shape has a different formula for calculating its area and perimeter.
#
# To implement this program, you decide to use polymorphism, where each shape is represented by its own class with its own methods for calculating area. The program should be able to accept inputs for the dimensions of the different shapes and calculate their respective areas.

# %%
class Shape:
    # Define abstract methods to calculate area and perimeter. Will be implemented by child classes.
    def area(self):
        pass

    def perimeter(self):
        pass


class Square(Shape):
    # Define the constructor method to initialize the class with the length of the side
    def __init__(self, side):
        self.side = side

    # Override the area method to calculate the area of the square
    def area(self):
        return self.side ** 2


class Rectangle(Shape):
    # Define the constructor method to initialize the class with the width and height
    def __init__(self, width, height):
        self.width = width
        self.height = height

    # Override the area method to calculate the area of the rectangle
    def area(self):
        return self.width * self.height


class Circle(Shape):
    # Define the constructor method to initialize the class with the radius
    def __init__(self, radius):
        self.radius = radius

    # Override the area method to calculate the area of the circle
    def area(self):
        return 3.14 * self.radius ** 2

# %% [markdown]
# In this example, we define a base class Shape that has two methods, area and perimeter. We then create three child classes, Square, Rectangle, and Circle, that inherit from the Shape class and override the area and perimeter methods with their own formulas

# %%
# Creating Objects of Shape Classes
square = Square(5)
rectangle = Rectangle(3, 4)
circle = Circle(2)

# Calculating Area and Perimeter of Shapes
print("Area of Square:", square.area())

print("Area of Rectangle:", rectangle.area())

print("Area of Circle:", circle.area())
# Out:
# Area of Square: 25
# Area of Rectangle: 12
# Area of Circle: 12.56

# %% [markdown]
# ### **Bank Account Management System** 💻🏦
#
# Create a Bank Account Management System using Object-Oriented Programming (OOPs) in Python. The system should allow users to create and manage bank accounts, deposit and withdraw funds, and view account details.

# %%
# Define a BankAccount class
class BankAccount:

    # Constructor to initialize account details
    def __init__(self, name, account_number, balance):
        self.name = name
        self.account_number = account_number
        self.balance = balance

    # Method to deposit funds into the account
    def deposit(self, amount):
        self.balance += amount
        print("Deposit successful. Your new balance is:", self.balance)

    # Method to withdraw funds from the account
    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print("Withdrawal successful. Your new balance is:", self.balance)
        else:
            print("Insufficient balance. Your current balance is:", self.balance)

    # Method to view account details
    def account_details(self):
        print("Name:", self.name)
        print("Account Number:", self.account_number)
        print("Balance:", self.balance)

# %%
# Test Case

# Create a new bank account
account1 = BankAccount("John Doe", "1234567890", 1000)

# Test deposit method
account1.deposit(500)

# Test withdraw method
account1.withdraw(2000)

# Test account details method
account1.account_details()

# %% [markdown]
# ##**Inheritance**

# %% [markdown]
# Inheritance is a core concept in object-oriented programming, which allows a new class to be based on an existing class. Inheritance provides a way to create a new class by absorbing the properties and behaviors of an existing class, while also allowing for the new class to add or modify its own unique properties and behaviors.

# %% [markdown]
# Let's consider an example of inheritance using a program that models different types of vehicles. We can define a base class called Vehicle that contains common properties and methods that are shared by all types of vehicles.

# %%
class Vehicle:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def start_engine(self):
        print("Starting engine...")

# %% [markdown]
# We can then define a subclass called Car that inherits from the Vehicle class and adds its own unique properties and methods.

# %%
class Car(Vehicle):
    def __init__(self, make, model, year, num_doors):
        super().__init__(make, model, year)
        self.num_doors = num_doors

    def drive(self):
        print("Driving the car...")

# %% [markdown]
# In this example, the Car class inherits from the Vehicle class using the super() function. This means that the Car class will have access to all the properties and methods of the Vehicle class. The __init__() method of the Car class overrides the __init__() method of the Vehicle class to include an additional parameter for the number of doors. The drive() method is unique to the Car class and is not present in the Vehicle class.
#
# Now, we can create instances of both the Vehicle and Car classes and call their respective methods.

# %%
vehicle = Vehicle("Toyota", "Corolla", 2022)
car = Car("Tesla", "Model S", 2021, 4)

vehicle.start_engine()  # prints "Starting engine..."
car.start_engine()      # prints "Starting engine..."

#vehicle.drive()       # This will produce an error, as the drive() method is not defined for the Vehicle class
car.drive()
# Out:
# Starting engine...
# Starting engine...
# Driving the car...

# %% [markdown]
# As we can see from this example, the Car class inherits properties and methods from the Vehicle class and adds its own unique functionality. This allows us to write more concise and modular code, as we can define generic behavior in the base class and specialize that behavior in the subclasses.
#
# ---

# %% [markdown]
# ##**Activity 3:**

# %% [markdown]
# ### **Spot the Error in the code**

# %% [markdown]
# **Question 1:**
# What is the possible issue with the following code snippet?
#
# ```
# class Rectangle:
#     def __init__(self, width, height):
#         self.width = width
#         self.height = height
#
#     def area(self):
#         return self.width * self.height
#
# class Square(Rectangle):
#     def __init__(self, side):
#         self.side = side
#         super().__init(side, side)
#
# rectangle = Rectangle(5, 3)
# square = Square(4)
# print(rectangle.area())
# print(square.area())
#
# ```
#
#
# **Question 2:**
# What is the potential problem with the following code snippet that demonstrates inheritance and polymorphism in Python?
#
# ```
# class Shape:
#     def area(self):
#         pass
#
# class Circle(Shape):
#     def __init__(self, radius):
#         self.radius = radius
#
#     def area(self):
#         return 3.14 * self.radius * self.radius
#
# class Square(Shape):
#     def __init__(self, side):
#         self.side = side
#
#     def area(self):
#         return self.side * self.side
#
# def print_area(shape):
#     print("Area:", shape.area())
#
# circle = Circle(5)
# square = Square(4)
# print_area(circle)
# print_area(square)
#
# print_area(triangle)
# ```

# %% [markdown]
# #### **Answers**

# %% [markdown]
# 1. **Answer:**
#     The error is coming in super().__init(side,side)
#
# ```
# class Rectangle:
#     def __init__(self, width, height):
#         self.width = width
#         self.height = height
#
#     def area(self):
#         return self.width * self.height
#
# class Square(Rectangle):
#     def __init__(self, side):
#         super().__init__(side, side)  # Call the superclass's __init__ method
#         self.side = side
#
# rectangle = Rectangle(5, 3)
# square = Square(4)
# print(rectangle.area())
# print(square.area())
#
# ```
#
#
# 2. **Answer:**
#
# The error in that code is we are calling undefined method
#
#
#
# ```
# class Shape:
#     def area(self):
#         pass
#
# class Circle(Shape):
#     def __init__(self, radius):
#         self.radius = radius
#
#     def area(self):
#         return 3.14 * self.radius * self.radius
#
# class Square(Shape):
#     def __init__(self, side):
#         self.side = side
#
#     def area(self):
#         return self.side * self.side
#
# def print_area(shape):
#     print("Area:", shape.area())
#
# circle = Circle(5)
# square = Square(4)
# print_area(circle)
# print_area(square)
# ```

# %% [markdown]
# # **✅ Summary ✅**

# %% [markdown]
# ##**What did you Learn?**
#
# * 🐍 Object-oriented programming (OOPs) in Python revolves around creating and manipulating objects that encapsulate data and behavior.
#
# * 👥 Python supports essential OOPs concepts such as inheritance, polymorphism, encapsulation, and abstraction. You can define and create these objects using the class and object keywords.
#
# * ✨ To define behaviors for built-in operations, Python offers special methods called "magic methods."
#
# Overall, OOPs concepts in Python provide a powerful way to organize and structure code, making it more maintainable and easier to extend.

# %% [markdown]
# ###**Best Practices/Tips**
#
# * Keep classes simple and focused on a single responsibility. This makes them easier to understand, test, and maintain.
# * Use meaningful class and method names that accurately describe their purpose and behavior.
# * Follow the Single Responsibility Principle (SRP) to ensure that each class has only one reason to change. This helps to reduce code complexity and improve maintainability.
# * Use private and protected attributes to enforce encapsulation and prevent direct access to class data from outside the class.
# * Use inheritance sparingly and only when necessary. Inheritance can lead to complex and brittle code, so it's important to keep class hierarchies shallow and simple.
# * Use composition to build complex objects from simpler ones. This allows for greater flexibility and modularity in the code.
# * Avoid using global variables and functions as they can make the code harder to test and maintain. Instead, use instance variables and methods within classes.
# * Use docstrings to document classes and methods. This makes it easier for others to understand and use your code.
# Take advantage of Python's built-in dunder methods to customize the behavior of objects and operators.
# * Use code linters and static analysis tools to ensure adherence to best practices and avoid common errors.

# %% [markdown]
# ###**Shortcomings**
# * Overhead: OOPs in Python can be slower than procedural programming due to the overhead of creating objects and invoking methods.
# * Memory Consumption: As objects are created dynamically in Python, memory consumption can be higher in OOPs programs compared to procedural programs.
# * Complexity: OOPs can add complexity to code, making it harder to read and understand, especially for beginners.
# * Inflexibility: In some cases, OOPs scan be inflexible as it may be harder to make certain changes or modifications to the program, especially when dealing with complex inheritance hierarchies.
# * Difficulty in Debugging: Debugging OOPs programs can be more difficult than debugging procedural programs, especially when dealing with complex inheritance hierarchies or interactions between objects.
# * Not Suitable for All Problems: OOPs may not be the best approach for all programming problems. Some problems may be better suited to procedural programming, functional programming, or other paradigms.

# %% [markdown]
# # **➕ Additional Reading ➕**

# %% [markdown]
# ###**Mnemonic**
#
# 👨‍💻 Once upon a time, there was a tech startup named Almabetter that offered online coding courses to aspiring programmers. The company hired a Python developer named Bob to build a new system to manage student records.
#
# 🐍 Bob decided to use object-oriented programming (OOPs) concepts in Python to build the system. He created a Student class with attributes such as name, age, and course enrollment status. He also created methods such as enroll() and drop_course() to allow students to change their course status.
#
# 📚 To manage student records, Bob created a StudentRecord class that contained a list of Student objects. The StudentRecord class had methods such as add_student() and remove_student() to allow the system administrators to manage the student database.
#
# 🤝 The Almabetter management was impressed with the system that Bob built using OOPs in Python. They found it to be more efficient, modular, and maintainable than their previous system.
#
# 🔧 Bob's use of OOPs in Python helped to create a scalable and adaptable system that could easily accommodate future changes and updates.
#
# 🎉 In the end, Almabetter's student record system built with OOPs in Python helped the company to grow and expand, and Bob was hailed as a hero for his excellent coding skills.

# %% [markdown]
# ## **Additional Reading**

# %% [markdown]
# ### Encapsulation

# %% [markdown]
# Encapsulation is a core concept in object-oriented programming that refers to the practice of hiding the internal workings of an object and exposing only the necessary interfaces to the outside world. This allows for better organization and abstraction of code, as well as improved security and maintainability.
#
# ![enca.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Let's consider an example of encapsulation using a program that models a bank account. We can define a class called BankAccount that contains the necessary properties and methods for managing a bank account.

# %%
class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds")
        else:
            self.balance -= amount

    def get_balance(self):
        return self.balance

# %% [markdown]
# In this example, the BankAccount class has an attribute called balance that represents the current balance of the account. The class provides three methods: deposit(), withdraw(), and get_balance(). These methods allow us to interact with the balance attribute in a controlled and secure way.

# %% [markdown]
# Notice that the balance attribute is not directly accessible from outside the class. Instead, we must use the provided methods to modify or access the balance. This is an example of encapsulation, as the internal workings of the BankAccount class are hidden from the outside world, and only the necessary interfaces are exposed.

# %% [markdown]
# Now, we can create an instance of the BankAccount class and interact with it using the provided methods.

# %%
account = BankAccount(1000)

account.deposit(500)
print(account.get_balance())   # prints 1500

account.withdraw(2000)         # prints "Insufficient funds"
account.withdraw(1000)
print(account.get_balance())   # prints 500
# Out:
# 1500
# Insufficient funds
# 500

# %% [markdown]
# As we can see from this example, the BankAccount class provides a secure and controlled way to manage the balance of a bank account. Encapsulation allows us to hide the internal details of the class and expose only the necessary interfaces, which makes the code more organized, secure, and maintainable.

# %% [markdown]
# ### Data Abstraction

# %% [markdown]
# Data abstraction is a core concept in object-oriented programming that refers to the practice of representing complex real-world objects using simpler, more abstract models. Abstraction allows us to focus on the essential features of an object while hiding the irrelevant or complex details.

# %% [markdown]
# ![abss.png](data:image/png;base64,...)

# %% [markdown]
# Let's consider an example of data abstraction using a program that models different types of animals. We can define a base class called Animal that represents the common properties and behaviors of all animals.

# %%
class Animal:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def make_sound(self):
        pass

# %% [markdown]
# In this example, the Animal class has two attributes, name and age, that represent the name and age of the animal. The class also has a method called make_sound() that does not do anything, as the specific sound that an animal makes is different for each animal.

# %% [markdown]
# We can then define subclasses for specific types of animals, such as Cat and Dog, that inherit from the Animal class and provide their own implementations of the make_sound() method.

# %%
class Cat(Animal):
    def make_sound(self):
        print("Meow")

class Dog(Animal):
    def make_sound(self):
        print("Woof")

# %% [markdown]
# In this example, the Cat class and the Dog class are subclasses of the Animal class and provide their own implementations of the make_sound() method. This allows us to represent different types of animals using a simpler and more abstract model.

# %% [markdown]
# Now, we can create instances of the Cat and Dog classes and call their respective methods.

# %%
cat = Cat("Whiskers", 5)
dog = Dog("Fido", 3)

cat.make_sound()   # prints "Meow"
dog.make_sound()   # prints "Woof"
# Out:
# Meow
# Woof

# %% [markdown]
# As we can see from this example, the Animal class provides a simple and abstract representation of animals, while the subclasses provide specific implementations of the make_sound() method for each type of animal. This allows us to represent complex real-world objects using simpler and more abstract models, which makes the code more organized, readable, and maintainable.
#
# ---

# %% [markdown]
# ## **Additional Resources**

# %% [markdown]
# - [https://www.irjet.net/archives/V8/i3/IRJET-V8I3315.pdf](https://www.irjet.net/archives/V8/i3/IRJET-V8I3315.pdf)
#
# - [https://www.warse.org/IJATCSE/static/pdf/file/ijatcse401022021.pdf](https://www.warse.org/IJATCSE/static/pdf/file/ijatcse401022021.pdf)
#
# - [https://medium.com/pythoneers/mastering-the-art-of-object-oriented-programming-in-python-df04c83cc15b](https://medium.com/pythoneers/mastering-the-art-of-object-oriented-programming-in-python-df04c83cc15b)

# %% [markdown]
# # **Try it yourself📃 📟**
#
#
# Are you ready to put your coding skills to the test and gain practical knowledge? We have some exciting coding questions waiting for you to solve! 🚀
#
# Your task is to attempt the coding questions associated with this lesson. These challenges have been thoughtfully designed to reinforce your understanding of the concepts covered in the course. You can find them in your dashboard under this lesson.
#
# Don't be shy! Share your findings, experiences, and any insights you gained while tackling these coding questions on the AlmaBetter community platform. Engage in discussions, help each other out, and celebrate your victories together!
#
# Remember, coding is not just about learning theory; it's about applying that knowledge to solve real-world problems. So, dive in, experiment, and have fun while honing your coding skills!
# Let's learn, grow, and inspire each other as a vibrant community of passionate learners. Happy coding! 💻 😊

# %% [markdown]
# ## **Task 1:**

# %% [markdown]
# ### 🎨 **Paint Brush Class** 🖌️
#
# Create a Python class for a paint brush that has the following properties:
#
# * Size (small, medium, or large)
# * Color (red, blue, green, or yellow)
# * Brand (Winsor & Newton, Liquitex, or Grumbacher)
# * Type (round or flat)

# %%
#space for answering

# %% [markdown]
# Now, create an instance of the PaintBrush class with the following properties:
#
# * Size: medium
# * Color: red
# * Brand: Winsor & Newton
# * Type: round
# * Call the paint() method on the instance to simulate painting with the brush.

# %%
# Test Case
# Create an instance of PaintBrush
brush = PaintBrush("medium", "red", "Winsor & Newton", "round")

# Call the paint() method on the instance
brush.paint()

# %% [markdown]
# ***🏠 Take this activity home and let the us guide you on the path to code
# mastery! 🎵🎶💻***
#
# ***Solve the challenge at your own pace and explore the world of set comprehension as you embark on your coding journey. Remember, the key to success lies in practice and exploration. So, let the unique song names guide you and take you home to the realm of Python programming excellence! 🚀🌟🏡***

# %% [markdown]
# ## **Task 2:**

# %% [markdown]
# ####**🔵 After solving this question, how do you feel about your confidence level in this lesson? Share your experience and insights with your Cohort group on AlmaBetter's Community Platform.**
