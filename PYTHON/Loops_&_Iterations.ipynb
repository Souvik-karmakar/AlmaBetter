# %% [markdown]
# ## **Session Flow:**
#
# 👨🏻‍🎓 Learning Objective:
#
# * Introduction
# * Theme
# * Primary Goals
#
# 📝 Master 'for' loops
#
# - Familiarize yourself with the structure and syntax of a 'for' loop.
# - Iterate through different types of sequences, such as lists, tuples, and strings.
# - Practice using 'for' loops to solve various problems.
# * Activity 1
#
# ⏳ Learn 'while' loops
#
# - Understand the concept and syntax of 'while' loops.
# - Use conditions to control the execution of a 'while' loop.
# - Practice implementing 'while' loops to solve real-life problems.
#
# ⛔ Comprehend loop control statements
#
# - Discover the purpose and usage of loop control statements like 'break', 'continue', and 'pass'.
# - Learn how they help in controlling the flow of loops for specific scenarios.
#
# 🎯 Explore nested loops
# - Learn how to use loops within loops (nested loops) to solve more complex problems.
# - Understand the importance of nested loops and their practical applications.
# * Activity 2
#
# 🧩 Develop problem-solving skills
#
# - Apply your knowledge of loops and iterations to solve various real-life problems and programming challenges.
# - Gain confidence in using loops effectively and enhance your overall problem-solving abilities.
# * Activity 3
#
# 📝 Summary
#
# * What did we learn?
# * Shortcomings & Challenges
# * Best Practices & Tips
#
# 🔗 Enhance your Knowledge
#
# * Mnemonic
# * Additional Resources
#
# 🔍 Try it Yourself
#
# * Activities
# * Social Engagement

# %% [markdown]
# # **👨🏻‍🎓 Learning Objective 👨🏻‍🎓**

# %% [markdown]
# ### **Introduction**
#
#
# 🐍🔁 Loops and iterations are important concepts in Python programming that allow you to execute a block of code multiple times.
#
# 🔂 The loop construct in Python enables you to repeat a certain task until a certain condition is met, making it a powerful tool for automating repetitive operations.
#
# 👣 Iteration, on the other hand, refers to the process of iterating or going through a collection of elements one by one. This is done using iterable objects such as lists, tuples, and dictionaries, among others.
#
# 🔄 In Python, there are two main types of loops: the "for" loop and the "while" loop. The "for" loop is used to iterate over a collection of elements, while the "while" loop is used to execute a block of code repeatedly until a certain condition is met.
#
# ### 🎯 **Theme:  - Loops & Iterations** 🌪️🚀💻
#
# 🌊 Setting Sail: Venture into the uncharted waters of Python's loops and iterations, where endless possibilities await! ⛵️🗺️
# 🔍 The Navigator's Guide: Navigate through the fundamentals of loops, a compass to repetitive excellence! 🧭🔢
# 🔄 Unraveling the Time Travelers: Embark on an extraordinary journey with iterations, where time bends to your command! ⏳🌌
#
# 🌟 The Looping Odyssey: Experience the magic of looping structures, shaping your code's destiny with finesse! 🔁✨
# 💡 Mastering the Art of Iterations: Unleash the power of traversing strings, lists, and beyond, with grace and skill! 🔤🧩
# 🔃 Loop Control Strategies: Steer your course with break and continue, as you conquer coding obstacles! 🛠️🔒
#
# ###**Primary Goals**
# * Grasp the concept of loops and iterations 🔄: As a student, you should understand the fundamentals of loops, their importance in programming, and how they help automate repetitive tasks efficiently.
#
# * Master 'for' loops 📝: Familiarize yourself with the structure and syntax of a 'for' loop, and learn how to iterate through different types of sequences, such as lists, tuples, and strings. Practice using 'for' loops to solve various problems.
#
# * Learn 'while' loops ⏳: Understand the concept of 'while' loops and their syntax. Learn how to use conditions to control the execution of a 'while' loop, and practice implementing them to solve real-life problems.
#
# * Comprehend loop control statements ⛔: Discover the purpose and usage of loop control statements like 'break', 'continue', and 'pass'. Learn how they help in controlling the flow of loops for specific scenarios.
#
# * Explore nested loops 🎯: Learn how to use loops within loops (nested loops) to solve more complex problems. Understand the importance of nested loops and their practical applications.
#
# * Develop problem-solving skills 🧩: Apply your knowledge of loops and iterations to solve various real-life problems and programming challenges. This will help you gain confidence in using loops effectively and enhance your overall problem-solving abilities.
#
# * Best practices and optimization 🚀: Understand the importance of writing efficient and optimized loop structures, and learn how to avoid common pitfalls like infinite loops. Familiarize yourself with best practices to improve the performance of your code.
#
# So, get ready to explore the endless possibilities of Python programming for data science! We'll guide you through the basics and show you how to get started. 🤓

# %% [markdown]
# # **📖 Learning Material 📖**

# %% [markdown]
# Hello there!
#
# 🤓 Today's lesson is all about Loops & Iterations in programming, which are crucial techniques that allow you to automate repetitive tasks and process large sets of data efficiently.
#
# 🔍🔪 We'll dive into using Loops & Iterations of Python and play a critical role in programming. Loops are used in programming to repeat a block of code multiple times, which can be useful for automating repetitive tasks or performing operations on large sets of data. There are two main types of loops in Python: for loops and while loops.Iterations can also be controlled using loop control statements, such as break and continue, which allow you to exit or skip iterations based on certain conditions.
#
# 🔢🍴 By the end of this lesson, you'll have a solid grasp of how to utilize Loops and iterations in your code.
#
# 🚀 So, let's get started and learn these essential skills!

# %% [markdown]
# ##For Loops

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 📝 Overview:
# A for loop in Python is used to iterate over a sequence of elements, such as a list, tuple, string, or range. It allows you to perform a certain action for each element in the sequence.
#
# 📝 Syntax:
# The basic syntax of a for loop in Python is as follows:
#
#
#
# *for **variable** in **sequence**:*
#
#
#
# Here, variable is a variable that takes on the value of each element in the sequence, and sequence is the sequence of elements to be iterated over.
#
# 📝 Example:
# Here's an example of a for loop that iterates over a list of numbers and prints each number:

# %% [markdown]
# 📝 Scenarios:
# for loops can be used in a variety of scenarios, including:
#
# 1. Iterating over a list or other sequence to perform a certain action for each element.
# 2. Looping a specific number of times using the range() function.
# 3. Processing a file line by line using the open() and readline() functions.
# 4. Iterating over a dictionary to perform a certain action for each key-value pair.

# %% [markdown]
# 🍕 Let's say you have a list of pizza toppings, like ["pepperoni", "mushrooms", "olives", "sausage"]. Your task is to print each toppings in a different line individually. What would be your approach?

# %%
#Non Coder:

# Define a list of pizza toppings
toppings = ["pepperoni", "mushrooms", "olives", "sausage"]
print(toppings[0])
print(toppings[1])
print(toppings[2])
print(toppings[3])
# Out:
# pepperoni
# mushrooms
# olives
# sausage

# %% [markdown]
# But with knowledge of loops, things are much easier!!

# %%
#Coder

# Define a list of pizza toppings
toppings = ["pepperoni", "mushrooms", "olives", "sausage"]

# Loop through each topping in the list and print it out
for topping in toppings:
    print(topping)
# Out:
# pepperoni
# mushrooms
# olives
# sausage

# %% [markdown]
# 🔁 You can also use a loop to add new toppings to the list. Let's say you want to add "bacon", "peppers", and "pineapple". You can use a for loop and the "append" method to add each topping to the list:

# %%
# Add new toppings to the list using a loop and the append method
new_toppings = ["bacon", "peppers", "pineapple"]

for topping in new_toppings:
    toppings.append(topping)

# Print out the updated list of toppings
print(toppings)
# Out:
# ['pepperoni', 'mushrooms', 'olives', 'sausage', 'bacon', 'peppers', 'pineapple', 'bacon', 'peppers', 'pineapple']

# %% [markdown]
# 🍕 Now your list of pizza toppings will be ["pepperoni", "mushrooms", "olives", "sausage", "bacon", "peppers", "pineapple"].

# %% [markdown]
# ###🤔Do You Know?🤔

# %% [markdown]
# Although you can add elements from a list to another using for loops, a smarter way to do this would be to use extend() method. Let's see.

# %%
toppings = ["pepperoni", "mushrooms", "olives", "sausage"]
new_toppings = ["bacon", "peppers", "pineapple"]
toppings.extend(new_toppings[0:2])  #adding bacon and peppers to topping list
toppings
# Out:
# ['pepperoni', 'mushrooms', 'olives', 'sausage', 'bacon', 'peppers']

# %% [markdown]
# See? 😀
# You need to figure out the optimal way to perform a task. And your ability to do that would improve as much as you practice, and explore this exciting world of python. 🥳🥳

# %% [markdown]
# ## **Let us practice hands-on coding question:**

# %% [markdown]
# Write a program that takes a string as input and counts the number of vowels (a, e, i, o, u) in the string using a for loop.

# %%
# Take input from the user
string = input("Enter a string: ")

# Initialize a count variable to 0
count = 0

# Loop through each character in the string
for char in string:
    # Check if the character is a vowel
    if char in "aeiouAEIOU":
        # If it is, increment the count
        count += 1

# Print the count of vowels
print("The number of vowels in the string is:", count)
# Out:
# Enter a string: a
# The number of vowels in the string is: 1

# %% [markdown]
# ##**Activity 1**:

# %% [markdown]
# ### **Guess the word**

# %% [markdown]
# 1. I am a Python construct that repeats a sequence of actions a specific number of times. My structure resembles a conveyor belt, as I move through the elements of a sequence, performing tasks along the way. What am I?
#
# 2. I am the variable that iterates through each element of a sequence during a for loop. Think of me as the tour guide, leading you through a series of destinations. What is my name?
#
# 3. I am a scenario where a for loop becomes a powerful ally in your quest to analyze a list of values. I examine each element, gather insights, and present them in a clear summary. What is this scenario called?

# %% [markdown]
# #### **Answers**

# %% [markdown]
# 1. **Answer:** For Loop
#
# Explanation: The for loop in Python is a powerful construct that repeats a sequence of actions for each element of an iterable, such as a list or a string. It allows you to process data efficiently by automatically iterating through the elements, performing tasks as it progresses.
#
# 2. **Answer:** Iterator (or Loop Variable)
#
# Explanation: The variable used in a for loop to iterate through each element of a sequence is often referred to as the iterator or loop variable. It takes on the value of each element during each iteration, leading the loop through the elements one by one.
#
# 3. **Answer:** Looping through a List
#
# Explanation: In this scenario, a for loop is employed to iterate through each element of a list and perform specific operations on each element. It allows you to efficiently process and analyze the data in the list, extracting valuable information and presenting it in a meaningful way.

# %% [markdown]
# ##Generating numbers- range()

# %% [markdown]
# 📝 Overview:
# range() is a built-in Python function used to generate a sequence of numbers. It is commonly used for looping a specific number of times in a for loop. The range() function returns an object of the range class, which represents a sequence of numbers.
#
# 📝 Syntax:
# The basic syntax of the range() function is as follows:
#
# range(start, stop,step)

# %% [markdown]
# 📝 Example:
# Here's an example of how to use the range() function to generate a sequence of numbers and loop through them using a for loop:

# %%
# Loop through numbers from 0 to 4
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Loop through numbers from 2 to 8, incrementing by 2 each time
for i in range(2, 9, 2):
    print(i)
# Out:
# 2
# 4
# 6
# 8

# %% [markdown]
# 📝 Note:
# It's worth noting that in Python 3, range() returns a special type of object that behaves like a sequence but does not actually generate the entire sequence in memory. This can be more memory-efficient when dealing with large sequences. If you need to generate the entire sequence at once, you can convert the range() object to a list using the list() function.

# %% [markdown]
# ##Using Breaks & continue

# %% [markdown]
# 👋 Hi there! Loops and iterations are powerful tools in Python programming that allow you to repeat a set of instructions until a certain condition is met.
#
# Sometimes you might want to exit a loop early or skip over certain iterations. This is where the break and continue statements come in.
#
# 💥 The break statement is used to exit a loop prematurely. When the break statement is encountered inside a loop, the loop is immediately terminated and the program execution continues with the next statement outside of the loop.
#
# 🔜 Here's an example:

# %%
for i in range(10):
    if i == 5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# This code will print the numbers 0 through 4, and then exit the loop when i is equal to 5.

# %% [markdown]
# 💫 The continue statement is used to skip over certain iterations of a loop. When the continue statement is encountered inside a loop, the current iteration is skipped and the loop continues with the next iteration.
#
# 🔜 Here's an example:

# %%
for i in range(10):
    if i % 2 == 0:
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# This code will print all the odd numbers between 0 and 9. The continue statement skips over the even numbers and moves on to the next iteration of the loop.
#
# 🤝 In summary, the break and continue statements are useful tools for controlling the flow of a loop and can help you write more efficient and effective Python code.

# %% [markdown]
# ##Nested Loops in Python 🎯🐍

# %% [markdown]
# Imagine you're organizing a chess tournament 🏆. Your task is to bring together the players whose name start with 'A' or 'B' in one team, and 'C' or 'D' in another team.
#
# In Python, you can nest 'for' loops to do this. Let's take a closer look at how nested loops work using our chess tournament scenario:

# %%
tournament = [['Alice', 'Charlie'], ['Bob', 'Diana']]

team1=[]
team2=[]
for group in tournament:    # First Loop/ Outer Loop.
    for player in group:      #  Inner loop.
        if player[0]=='A' or player[0]=='B':
          team1.append(player)
        else:
          team2.append(player)

print(f'Team 1 is: {team1} \n And Team 2 is {team2}')
# Out:
# Team 1 is: ['Alice', 'Bob']
#  And Team 2 is ['Charlie', 'Diana']

# %% [markdown]
# In this example, we have two 'for' loops. The outer loop iterates through the players list, while the inner loop does the same. By using nested loops, we can generate the team of ['Alice', 'Bob']
# & ['Charlie', 'Diana'] using some conditions & indexing.

# %% [markdown]
# Nested loops may appear intimidating at first, but with practice, you'll find them to be powerful tools for tackling complex problems. Just remember to keep track of the loop variables and their respective ranges to avoid confusion! 😄

# %% [markdown]
# ## **Let us practice hands-on coding question:**

# %% [markdown]
# You're given a nested list of numbers, and your task is to count the number of odd and even numbers in the list. To achieve this, you'll use a nested loop and some basic conditional statements.
#
# List- numbers = [
#     [2, 5, 11, 20, 8],
#     [9, 4, 15, 28, 17],
#     [1, 6, 21, 18, 3],
#     [10, 13, 25, 33, 30],
#     [14, 7, 16, 19, 22]
# ]

# %%
# List of numbers
numbers = [
    [2, 5, 11, 20, 8],
    [9, 4, 15, 28, 17],
    [1, 6, 21, 18, 3],
    [10, 13, 25, 33, 30],
    [14, 7, 16, 19, 22]
]

# Initialize counters for odd and even numbers
even_count = 0
odd_count = 0

# Iterate through the main list and its sublists using nested loops
for sublist in numbers:
    for number in sublist:
        # Check if the number is odd or even and increment the counters accordingly
        if number % 2 == 0:
            even_count += 1
        else:
            odd_count += 1

# Print the total count of odd and even numbers
print(f"Total even numbers: {even_count}")
print(f"Total odd numbers: {odd_count}")

# %% [markdown]
# ##**Activity 2**:

# %% [markdown]
# ### **True or False**

# %% [markdown]
# **Statement 1:**
# True or False: The "break" statement in Python is used to terminate the execution of a loop when a certain condition is met.
#
# **Statement 2:**
# True or False: The "continue" statement in Python is used to skip the remaining code inside the loop and move to the next iteration when a certain condition is met.
#
# **Statement 3:**
# True or False: Nested for loops in Python allow you to loop through a sequence of elements within another loop.

# %% [markdown]
# #### **Answers**

# %% [markdown]
# **Statement 1:** True
#
# Explanation: The "break" statement in Python is used to terminate the execution of a loop prematurely when a specific condition is met. When encountered, the loop immediately exits, and the program continues with the code following the loop.
#
# **Statement 2:** True
#
# Explanation: The "continue" statement in Python is used to skip the remaining code inside the loop for the current iteration and proceed to the next iteration of the loop. When the "continue" statement is encountered, it jumps to the next iteration without executing any code that follows it in the current iteration.
#
# **Statement 3:** True
#
# Explanation: Nested for loops in Python allow you to have one loop inside another loop. This arrangement enables you to iterate through a sequence of elements within the outer loop and the inner loop.

# %% [markdown]
# ##Loops on different data types
# Let's dive right in and explore the amazing world of these loops and iterations in Python! By using these loops and iterations on different data structures, we can unlock their full potential and discover just how powerful they can be.

# %% [markdown]
# ### Lists

# %% [markdown]
# Imagine you are a teacher and you need to calculate the average grade for a class of 25 students. You have a list of grades for each student and you need to loop through the list to calculate the average grade for the class.
#
# Here's an example of how to use a for loop with a list to calculate the average grade for the class:

# %%
# Create a list of grades for each student
grades = [90, 85, 95, 80, 75, 85, 90, 85, 70, 80,
          90, 75, 80, 85, 90, 95, 80, 75, 85, 90,
          85, 90, 75, 80, 85]

# Use a for loop to calculate the total grade for the class
total_grade = 0
for grade in grades:
    total_grade += grade

# Calculate the average grade for the class
average_grade = total_grade / len(grades)

# Print the average grade for the class
print(f"The average grade for the class is {average_grade}.")
# Out:
# The average grade for the class is 83.8.

# %% [markdown]
# In this example, the for loop iterates through each item in the grades list and adds it to the total_grade variable. The average grade is then calculated by dividing the total grade by the number of students, and the result is printed to the console.

# %% [markdown]
# ### Strings
#
# Strings are also iterable objects in Python, which means you can use loops and iterations to access each character in the string.

# %% [markdown]
# Imagine you are a programmer working on a text editor application. You need to implement a feature that allows users to count the number of vowel in a string of text. You have a string containing the text and you need to loop through the string to search for the character.
#
# Here's an example of how to use a for loop with a string:

# %%
# for loop to count the number of vowels in a string
my_string = "Hello, World!"
count = 0
for char in my_string:
    if char in "aeiouAEIOU":
        count += 1
print(count)
# Out:
# 3

# %% [markdown]
# Let's now try using a while loop to reverse the given string:

# %%
# while loop to reverse a string
my_string = "Hello, World!"
reversed_string = ""
i = len(my_string) - 1
while i >= 0:
    reversed_string += my_string[i]
    i -= 1
print(reversed_string)
# Out:
# !dlroW ,olleH

# %% [markdown]
# ###Dictionaries:

# %% [markdown]
# Dictionaries in Python are incredibly useful when you need to store and manage data in key-value pairs. Imagine you're a librarian 📚, and you need to keep track of books and their authors. With dictionaries, you can easily achieve this!
#
# Let's take a look at how to loop through dictionaries and access their keys and values using different methods.

# %% [markdown]
# Scenario 1: Looping through keys 🗝️
#
# You want to print out all the books in your library. To do this, you can loop through the dictionary keys:

# %%
library = {
    'To Kill a Mockingbird': 'Harper Lee',
    '1984': 'George Orwell',
    'The Catcher in the Rye': 'J.D. Salinger',
    'The Great Gatsby': 'F. Scott Fitzgerald'
}

for book in library:
    print(book)
# Out:
# To Kill a Mockingbird
# 1984
# The Catcher in the Rye
# The Great Gatsby

# %% [markdown]
# Scenario 2: Looping through values 📖
#
# Now, you want to print out all the authors in your library. To do this, you can loop through the dictionary values:

# %%
for author in library.values():
    print(author)
# Out:
# Harper Lee
# George Orwell
# J.D. Salinger
# F. Scott Fitzgerald

# %% [markdown]
# Scenario 3: Looping through both keys and values 🗝️📖
#
# Finally, you want to print out both the books and their authors. To do this, you can loop through the dictionary items (key-value pairs):
#
#
# (You can find more about item() in "Do you know?" section below)

# %%
for book, author in library.items():
    print(f"{book} is written by {author}")
# Out:
# To Kill a Mockingbird is written by Harper Lee
# 1984 is written by George Orwell
# The Catcher in the Rye is written by J.D. Salinger
# The Great Gatsby is written by F. Scott Fitzgerald

# %% [markdown]
# ## **Let us practice hands-on coding question:**

# %% [markdown]
# 1. You work for a small coffee shop, and your boss has asked you to create a program that will calculate the total revenue for each day of the week. You have a dictionary containing the daily sales for the past week, and you need to loop through the dictionary to calculate the revenue and add it to previous week's daily revenue data. Write a program that calculates the total revenue for each day of the week using a loop and prints the results.

# %% [markdown]
# Write a program that calculates the total revenue for each day of the week using a loop and prints the results.

# %%
#Below we have revenue for previous week. Update this and add this week's revenue as well.
revenue = {
    'Monday': 250,
    'Tuesday': 230,
    'Wednesday': 45,
    'Thursday': 100,
    'Friday': 109,
    'Saturday': 234,
    'Sunday': 567
}

for day, sales_amount in sales.items():
    revenue[day] += sales_amount

for day, revenue_amount in revenue.items():
    print(f"{day}: ${revenue_amount}")
# Out:
# Monday: $600
# Tuesday: $650
# Wednesday: $345
# Thursday: $600
# Friday: $709
# Saturday: $1034
# Sunday: $1267

# %% [markdown]
# 2. You and your friends are playing a board game where you roll a dice and move your game piece accordingly. However, you want to know the average number rolled by each player to see who's really the luckiest. Write a program that takes a list of rolls as input for each player and uses a for loop to calculate the average roll for each player. The winner gets bragging rights for being the luckiest!

# %%
# define a list of rolls for each player
player_rolls = [
    [4, 2, 6, 3, 1],  # player 1's rolls
    [3, 5, 6, 4, 2],  # player 2's rolls
    [1, 2, 2, 6, 4]   # player 3's rolls
]

# create an empty list to store each player's average roll
average_rolls = []

# loop through each player's rolls
for i, rolls in enumerate(player_rolls, 1):
    # calculate the average roll for the player using the sum() and len() functions
    # hint: the formula for average is sum of rolls divided by number of rolls
    avg_roll = sum(rolls) / len(rolls)

    # add the player's average roll to the list of average rolls
    average_rolls.append(avg_roll)

# loop through each player's average roll and print it out with the player number
for i, avg_roll in enumerate(average_rolls):
    print(f"Player {i+1}'s average roll: {avg_roll}")
# Out:
# Player 1's average roll: 3.2
# Player 2's average roll: 4.0
# Player 3's average roll: 3.0

# %% [markdown]
# ##**Activity 3**:

# %% [markdown]
# ### **Fill in the blanks with the appropriate key word for the given looping scenarios**

# %% [markdown]
# 1. To practice iterating through a list of colors, you can use a _________ loop. It allows you to access each color one by one, starting from the first color until the last.
#
# 2. If you want to calculate the sum of the first 10 positive integers, you can use a _________ loop. It executes the addition operation a specified number of times.
#
# 3. For examining each character in a DNA sequence and counting the occurrences of a specific nucleotide (e.g., 'A'), a _________ loop can be employed. It iterates through each character, helping you analyze and tally the occurrences.
#
# 4. To pair corresponding items from two different grocery lists and create a shopping list, you can utilize a _________ loop. It pairs items with the same index in both lists, creating a consolidated list.
#
# 5. When searching for the first occurrence of a particular word in a text document, a _________ loop can be effective. It allows you to look for the word and stop searching once it's found. You can use a _________ loop with an "if" statement and a "break" statement for this task.

# %% [markdown]
# #### **Answers**

# %% [markdown]
# 1. To practice iterating through a list of colors, you can use a "for loop." It allows you to access each color one by one, starting from the first color until the last. A for loop is ideal for this task as it iterates over the elements in a sequence (in this case, a list) in a predictable and systematic manner.
#
# 2. If you want to calculate the sum of the first 10 positive integers, you can use a "for loop." It executes the addition operation a specified number of times. In this case, a for loop with a counter variable that goes from 1 to 10 would allow you to sum these integers.
#
# 3. For examining each character in a DNA sequence and counting the occurrences of a specific nucleotide (e.g., 'A'), a "for loop" can be employed. It iterates through each character, helping you analyze and tally the occurrences. A for loop is suitable for this task because it allows you to traverse the characters one by one and perform character-specific analysis.
#
# 4. To pair corresponding items from two different grocery lists and create a shopping list, you can utilize a "for loop" with the zip function. It pairs items with the same index in both lists, creating a consolidated list. You can use zip within a for loop to iterate through multiple lists simultaneously and combine corresponding elements.
#
# 5. When searching for the first occurrence of a particular word in a text document, a "while loop" can be effective. It allows you to look for the word and stop searching once it's found. You can use a "while loop" with an "if" statement and a "break" statement for this task because it continues searching until a specific condition (finding the word) is met, and then it breaks out of the loop.

# %% [markdown]
# ## 🤔Do You Know?🤔

# %% [markdown]
# In the context of Python dictionaries, "items" refer to the key-value pairs that make up the dictionary. Each item consists of a key and its associated value. The items() method in Python returns a view object that displays a list of a dictionary's key-value tuple pairs.
#
# For example, consider the following dictionary:

# %%
person = {
    'name': 'Alice',
    'age': 30,
    'city': 'New York'
}

# %% [markdown]
# The items in this dictionary are:
#
# 'name': 'Alice'
#
# 'age': 30
#
# 'city': 'New York'
#
# You can use the items() method to loop through the key-value pairs of a dictionary:

# %%
for key, value in person.items():
    print(f"{key}: {value}")
# Out:
# name: Alice
# age: 30
# city: New York

# %% [markdown]
# The items() method is particularly useful when you need to work with both keys and values simultaneously while iterating through a dictionary.

# %% [markdown]
# ## **You made it to end!!:**

# %% [markdown]
# 🎉🎉🎉 Congratulations on mastering the art of loops and iterations in Python! 🔁🔂 With these tools, you can efficiently execute a set of instructions repeatedly, or iterate over each element of a sequence or collection. 💪 These skills will empower you to write concise, readable, and efficient code to handle complex data manipulation tasks. 🚀 So, go ahead and explore the vast world of Python with confidence, and unlock its full potential! 💻🐍

# %% [markdown]
# # **✅ Summary ✅**

# %% [markdown]
# ## **What Did You Learn?**

# %% [markdown]
# 🔁 Loops and iterations are used in Python to execute a set of instructions repeatedly or to go through each element in a sequence or collection.
#
# 🐍 Python has two types of loops: for loops and while loops. For loops are commonly used for iterating over a sequence, while while loops are used for executing a block of code repeatedly as long as a condition is true.
#
# 🔍 When working with loops and iterations, you can use keywords like "break" and "continue" to modify the behavior of the loop.
#
# 🌟 Loops and iterations are essential for handling and manipulating data structures like strings, lists, tuples, and dictionaries in Python.
#
# 💪 By mastering loops and iterations, you can write concise, readable, and efficient code to handle complex data manipulation tasks and unlock the full potential of Python.

# %% [markdown]
# ## **Best Practices /Tips**

# %% [markdown]
# 1. **Plan your loops carefully:** Before writing a loop, take a moment to think about the problem you're trying to solve and how you want to iterate through the data. This can help you avoid errors and make your code more efficient.
#
# 2. **Use descriptive variable names:** When using loop variables, choose descriptive names that reflect what they represent. This can help make your code more readable and easier to understand.
#
# 3. **Use range() when working with indices:** If you need to access specific elements in a list or other iterable, use the range() function to generate a sequence of indices. This can make your code more concise and easier to understand.
#
# 4. **Avoid modifying the iterable inside the loop:** When looping through an iterable, avoid modifying the iterable itself, as this can lead to unexpected behavior. Instead, create a copy of the iterable or use a different approach to avoid modifying the original data.
#
# 5. **Use list comprehension when appropriate:** When you need to create a new list based on an existing iterable, consider using list comprehension. This can simplify your code and make it more readable.
#
# 6. **Keep your loops simple:** As a general rule, it's best to keep your loops simple and easy to understand. Complex nested loops can be difficult to debug and maintain over time.

# %% [markdown]
# ## **Shortcomings**

# %% [markdown]
# 1. **Time complexity:** Loops can be time-consuming, especially when working with large datasets or nested loops. It's important to be mindful of the time complexity of your loops and find ways to optimize them when necessary.
#
# 2. **Infinite loops:** It's easy to create an infinite loop by mistake, which can cause your program to crash or hang indefinitely. To avoid this, always double-check your loop conditions and ensure that they will eventually exit.
#
# 3. **Memory usage:** Depending on how you use loops, they can consume a lot of memory. For example, creating a large list using a loop can quickly consume a lot of memory. To avoid this, consider using generators or other memory-efficient techniques.
#
# 4. **Complexity:** Nested loops can quickly become complex and difficult to read, especially if they are deeply nested. It's important to keep your code organized and well-structured to avoid confusion and errors.
#
# 5. Limited access to previous iterations: In some cases, you may need to access the results of previous iterations in your loop. However, this can be difficult to do with standard loops. In these cases, consider using a more advanced technique, such as recursion or dynamic programming, which we can learnl later on.

# %% [markdown]
# # **➕ Additional Reading ➕**

# %% [markdown]
# ## **Mnemonic**
#
# Once upon a time in the beautiful town of Codeville, four young friends named Alice, Bob, Carol, and Dave were known for their exceptional problem-solving skills. They were often approached by the townspeople to help with various challenges using their coding knowledge. 🏘️💡
#
# One sunny day ☀️, the mayor of Codeville came to the four friends with an urgent request. The town's water supply system had malfunctioned, and they needed to calculate the total water consumption of the town to fix the issue. The water consumption data for every household was stored in a list, and the friends knew that they could use a loop to find the solution.
#
# Alice, the expert in for-loops, suggested, "Let's use a for-loop to iterate through the list and sum the water consumption of each household." 💧🔄 With her brilliant idea, the friends quickly calculated the total water consumption and helped the mayor resolve the problem.
#
# A few days later, the local library 📚 needed assistance in organizing their books. They wanted to sort books alphabetically by the author's last name. Carol, who loved working with while-loops, said, "We can use a while-loop to implement a sorting algorithm and rearrange the books accordingly." The friends worked together, using loops and iterations to sort the books, making the library more organized and efficient.
#
# One evening, the friends decided to participate in Codeville's annual stargazing event 🌟. To win the event, they had to count the total number of stars visible in the night sky. They observed that the stars were arranged in a grid pattern, and they realized that they could use nested loops to count them.
#
# Dave, who had a knack for nested loops, proposed, "We can use a nested loop, where the outerloop represents rows and the inner loop represents columns. We can iterate through each position in the grid and count the stars." 🌌🌀
#
# With their combined knowledge and skills, the friends worked tirelessly, using nested loops to count the stars and win the competition. They celebrated their victory with a delicious pizza party 🍕🎉, grateful for their teamwork and problem-solving abilities.
#
# In the end, the four friends became known as the problem-solving wizards of Codeville. They continued to use loops and iterations to overcome various challenges in their town, leaving a positive impact on the community. 🙌

# %% [markdown]
# ## **Additional Reading: Loops & Iterations**

# %% [markdown]
# ### Tuples
#
# Tuples are also iterable objects in Python, which means you can use loops and iterations to access each element in the tuple

# %% [markdown]
# Scenario 1: Looping through tuple elements directly 📚
#
# You want to print out all the grades in your tuple. To do this, you can loop through the tuple elements directly:

# %%
grades = (90, 78, 85, 92, 76, 88, 79)

for grade in grades:
    print(grade)
# Out:
# 90
# 78
# 85
# 92
# 76
# 88
# 79

# %% [markdown]
# Scenario 2: Looping through tuple elements using index 🏷️
#
# Now, you want to print out the grades along with their index (position). To do this, you can loop through the tuple using the range() function and len() function to get the indices of the tuple elements:

# %%
for index in range(len(grades)):
    print(f"Grade {index + 1}: {grades[index]}")
# Out:
# Grade 1: 90
# Grade 2: 78
# Grade 3: 85
# Grade 4: 92
# Grade 5: 76
# Grade 6: 88
# Grade 7: 79

# %% [markdown]
# Scenario 3: Looping through tuple elements using the enumerate() function 🔢
#
# Alternatively, you can use the built-in enumerate() function to loop through the tuple elements along with their indices in a more concise way:
#
# (You can find more about enumerate() in "Do you know?" section below)

# %%
for index, grade in enumerate(grades):
    print(f"Grade {index + 1}: {grade}")
# Out:
# Grade 1: 90
# Grade 2: 78
# Grade 3: 85
# Grade 4: 92
# Grade 5: 76
# Grade 6: 88
# Grade 7: 79

# %% [markdown]
# Looping through tuples is a convenient way to access and work with elements in an ordered, immutable collection. By using different looping techniques, you can efficiently iterate through tuple elements based on your needs. 🚀

# %% [markdown]
# ### 🤔Do You Know?🤔

# %% [markdown]
# enumerate() is a built-in Python function that allows you to loop through an iterable (like a list, tuple, or string) and keep track of the index (position) of the current item, along with the item itself. It simplifies your code when you need to perform operations that require both the element and its index.
#
# enumerate() takes an iterable as its argument and returns an enumerate object, which is an iterator containing pairs of indices and elements. You can loop through this enumerate object using a for loop.
#
# Here's an example using enumerate() to loop through a list of colors:

# %%
colors = ['red', 'green', 'blue', 'yellow']

for index, color in enumerate(colors):
    print(f"Color {index + 1}: {color}")
# Out:
# Color 1: red
# Color 2: green
# Color 3: blue
# Color 4: yellow

# %% [markdown]
# ## **Additional Resources**

# %% [markdown]
# - [https://medium.com/geekculture/loops-in-python-back-to-basics-7d305be3adf7](https://medium.com/geekculture/loops-in-python-back-to-basics-7d305be3adf7)
#
# - [https://www.sciencedirect.com/science/article/pii/S1110866523000166](https://www.sciencedirect.com/science/article/pii/S1110866523000166)
#
# - [https://python.plainenglish.io/a-comprehensive-guide-to-loops-in-python-e06b8814804f](https://python.plainenglish.io/a-comprehensive-guide-to-loops-in-python-e06b8814804f)
#
# - [http://ijariie.com/AdminUploadPdf/PROGRAMMING_LANGUAGE_PYTHON__A_REVIEW_ijariie11892.pdf](http://ijariie.com/AdminUploadPdf/PROGRAMMING_LANGUAGE_PYTHON__A_REVIEW_ijariie11892.pdf)

# %% [markdown]
# # **Try it Yourself 📃**
#
# Are you ready to put your coding skills to the test and gain practical knowledge? We have some exciting coding questions waiting for you to solve! 🚀
#
# Your task is to attempt the coding questions associated with this lesson. These challenges have been thoughtfully designed to reinforce your understanding of the concepts covered in the course. You can find them in your dashboard under this lesson.
#
# Don't be shy! Share your findings, experiences, and any insights you gained while tackling these coding questions on the AlmaBetter community platform. Engage in discussions, help each other out, and celebrate your victories together!
#
# Remember, coding is not just about learning theory; it's about applying that knowledge to solve real-world problems. So, dive in, experiment, and have fun while honing your coding skills!
# Let's learn, grow, and inspire each other as a vibrant community of passionate learners. Happy coding! 💻 😊

# %% [markdown]
# ## **Task 1:**

# %% [markdown]
# #### **🔴 Go to the AlmaBetter IDE on the Practice Tab and solve the coding questions specific to the lesson.🔴**

# %% [markdown]
# **Problem 1:** Pattern formation
#
#
# **Problem 2:** Reschedule the meeting to next date
#
#
# **Problem 3:** Check alphabet is consonant or vowel

# %% [markdown]
# ## **Task 2:**

# %% [markdown]
# ####**🔵 Go to the AlmaBetter Community and post about the concepts you got to know from today's lesson.**
