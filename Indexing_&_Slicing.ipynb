# %% [markdown]
# ## **Session Flow:**
#
# 👨🏻‍🎓 Learning Objective:
#
# * Introduction
# * Theme
# * Primary Goals
#
# 🎯 Understanding Indexing
#
# - Introduction to indexing in Python and its significance.
# - Basics of zero-based indexing for different data structures (strings, lists, tuples).
# - Accessing individual elements using positive and negative indexing.
# - Practical examples of indexing in various scenarios.
# * Activity 1
# * Activity 2
#
# 🎯 Exploring Slicing
#
# - Introduction to slicing and its role in data extraction.
# - Syntax of slicing to extract portions of data from strings and lists.
# - Slicing with start, stop, and step parameters to control the extraction.
# - Examples of using slicing to reverse, skip elements, or get sublists.
#
# 🔠🔪 Indexing and Slicing in Strings
#
# - Understanding how indexing and slicing work on string data.
# - Extracting individual characters and substrings from strings.
# - Using slicing to modify or manipulate strings.
# - Exploring common string methods for practical data processing.
# * Activity 3
#
# 🎯🔪 Indexing and Slicing in Lists and Tuples
#
# - Applying indexing and slicing techniques to lists and tuples.
# - Extracting specific elements or sublists from lists.
# - Modifying list elements using indexing and slicing.
# - Working with nested lists and tuples using advanced slicing.
#
# 📝 Summary
#
# * What did we learn?
# * Shortcomings & Challenges
# * Best Practices & Tips
#
# 🔗 Enhance your Knowledge
#
# * Mnemonic
# * Additional Resources
#
# 🔍 Try it Yourself
#
# * Activities
# * Social Engagement

# %% [markdown]
# # **👨🏻‍🎓 Learning Objective 👨🏻‍🎓**

# %% [markdown]
# ##**Introduction**
#
# 🐍 In Python, slicing and indexing 📜 are fundamental techniques that enable you to access specific elements within a sequence 📊, including strings 🔡, lists 📃, tuples and more.
#
# 🔎 Indexing helps retrieve individual elements from a sequence by their position, while slicing enables you to extract a range of elements from a sequence.
#
# To explore the power of indexing and slicing, we will use different data types  to demonstrate how they work, and understand how they differ from one another. Get ready to dive into the world of slicing and indexing in Python

# %% [markdown]
# ### **Theme**
#
#  In this lesson, we'll dive deep into the art of indexing and slicing, your secret superpowers to access specific parts of your data.
#
# Just like selecting individual letters from a word or extracting a range of elements from a list, indexing and slicing allow you to retrieve and manipulate precise portions of your data. It's like having a magnifying glass to zoom in on what you need. With these incredible techniques, you'll gain the ability to slice and dice your data, opening up a world of possibilities for efficient data extraction and manipulation.  🚀🔎📚

# %% [markdown]
# ##**Primary Goals**
#
# 1. Access and manipulate individual elements or subsets of elements in lists, tuples, strings, and other data structures.
# 2. Improve efficiency by avoiding iterating over all elements in a data structure.
# 3. Improve code readability and reduce the likelihood of errors by using concise and straightforward syntax.
# 4. Prepare for more advanced programming tasks in data science, machine learning, and other fields we will explore in future lessons.

# %% [markdown]
# # **📖 Learning Material 📖**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 📝 Hey there! In this lesson, you'll be learning about indexing and slicing operations in programming. 🤓 These are essential techniques for accessing and manipulating specific elements in a sequence, such as strings or lists. 🔍🔪 We'll explore how to use index numbers to retrieve individual elements and how to slice a sequence to extract a portion of it. 🔢🍴 By the end of this lesson, you'll understand how to work with indexing and slicing in your code. Let's get started! 🚀

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 📜 First of all, let's start with indexing. Indexing is simply accessing an element in a sequence or a list by its position. You can think of it as finding a specific book page using the page number. In Python, **indexing starts at 0, which means the first element in a sequence has an index of 0**, the second has an index of 1, and so on.
#
# 🍕 Here's an example: Imagine you have a list of your favorite pizza toppings, like ["pepperoni," "mushrooms," "olives," "sausage"]. If you want to access the second item in the list, which is "mushrooms," you can use indexing like this: toppings[1]. This will return "mushrooms" since it has an index of 1.
#
# 🔪 Now, let's move on to slicing. Slicing is a way to extract a portion of a sequence or a list. In Python, you can slice a sequence or a list using a start index, an end index, and an optional step value. It's like cutting a slice of cake out of a larger cake.
#
# 🎂 Here's an example: Let's say you have a cake with 8 slices, and you want to take a slice from the 2nd to the 5th slice. You can use slicing like this: cake[1:5]. This will return a list of cake slices from index 1 to index 4, which includes the 2nd, 3rd, 4th, and 5th slices.
#
# 📊 Slicing is also commonly used in data analysis and visualization. For example, if you have a large dataset of customer information, you can use slicing to extract a specific subset of the data based on certain criteria. This can help you identify patterns and trends in the data more quickly.
#
# 👌 So, to sum it up: indexing is like finding a specific page in a book, and slicing is like cutting a slice of cake. Both indexing and slicing are powerful tools that can help you manipulate and analyze data in Python.

# %% [markdown]
# Remember that the indexing starts with 0 in Python
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Are Indexing and Slicing operations different for different data types?
#
# You should know that indexing and slicing operations remain mostly the same across different data types in Python. 🐍
#
# Whether you're working with a list 📜, tuple 🎊, string 🔤, or even a NumPy array 🧮, the basic syntax for indexing and slicing remains consistent.
#
# For example, to access the first element in a list, you would use indexing with an index of 0, like this: myList[0]. Similarly, to extract a slice of a string from the 2nd to the 5th character, you would use slicing like this: myString[1:5]. 🔍
#
# This consistency makes it easier to work with different data types in Python since you can use the same techniques across multiple data types. 💪
#
# Of course, there may be some differences in behavior depending on the data type, such as whether the data is mutable or immutable. Still, the basic principles of indexing and slicing remain the same. 💡
#
# So whether you're working with a list, tuple, string, or any other data type in Python, you can easily use indexing and slicing to access and manipulate the data. 🙌
#
# Let's explore indexing and slicing using different data types.

# %% [markdown]
# ##Indexing

# %% [markdown]
# 🔍 Different types of data structures have different indexing methods, but the general syntax is similar for all of them.

# %% [markdown]
# ###Strings
# 💬 Strings are a type of sequence in Python, which means that they can be indexed using the square bracket [] notation. Here's an example:

# %%
my_string = "Hello, world!"
print(my_string[0])   # Output: "H"
print(my_string[-1])   # Output: "!"
# Out:
# H
# !

# %% [markdown]
# 👉 In this example,
# * We used indexing to select the first element of the string using my_string[0]
# * And we retrieved the last element of the string using my_string[-1].

# %% [markdown]
# ####🧠 **Brain Teaser** 🧠
# * What would be the index of 'O's in 'my_string'?
#
# my_string = "Hello, world!"

# %% [markdown]
# ### **Solution**

# %% [markdown]
#  4,8

# %% [markdown]
# ###Tuples
# 📦 Tuples, similar to strings, can be indexed using the square bracket [] notation. Here's an example:

# %%
my_tuple = (1, 2, 3, 4, 5)
print(my_tuple[2])   # Output: 3
print(my_tuple[-1])   # Output: 5
# Out:
# 3
# 5

# %% [markdown]
# 👉 In this example,
# * We have used indexing to select the third element of the tuple using my_tuple[2]
# * And  the last element of the tuple using my_tuple[-1].

# %% [markdown]
# ####🧠 **Brain Teaser** 🧠
# * What would be the index of 4 in 'my_tuple'?
#
# my_tuple = (1, 2, 3, 4, 5)

# %% [markdown]
# ### **Solution**:

# %% [markdown]
# 3

# %% [markdown]
# ###Lists
# 📦 Lists are another type of sequence in Python, similar to tuples and strings, that can be indexed using the square bracket [] notation. Here's an example:

# %%
my_list = [1, 2, 3, 4, 5]
print(my_list[2])   # Output: 3
print(my_list[-1])   # Output: 5
# Out:
# 3
# 5

# %% [markdown]
# 👉 In this example,
# * We used indexing to select the third element of the list using my_list[2]
# * And  the last element of the list using my_list[-1].

# %% [markdown]
# ### 🧠 **Brain Teaser** 🧠
# * What would be the output of my_list[5] ?

# %% [markdown]
# ### **Solution**:

# %% [markdown]
# Error

# %%
#Let's try
print(my_list[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-f50dc4041051> in <cell line: 2>()
#       1 #Let's try
# ----> 2 print(my_list[5])
#
# IndexError: list index out of range

# %% [markdown]
# ###Sets
# 👥 Sets are an unordered collection of unique elements in Python, and they do not support indexing. Here's an example:

# %%
my_set = {1, 2, 3, 4, 5}
print(my_set[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-0dc9137360d6> in <cell line: 2>()
#       1 my_set = {1, 2, 3, 4, 5}
# ----> 2 print(my_set[2])
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ❌ In this example, we tried to index the third element of the set using my_set[2], but we got an error because sets do not support indexing.

# %% [markdown]
# ###Dictionaries
# 📚 Dictionaries are a collection of key-value pairs in Python, and they can be indexed using the keys. Here's an example:

# %%
my_dict = {"name": "John", "age": 30, "city": "New York"}
print(my_dict["name"])   # Output: "John"
print(my_dict["city"])   # Output: "New York"
# Out:
# John
# New York

# %% [markdown]
# 👉 In this example, we used indexing to select the value associated with the key "name" using my_dict["name"] and the value associated with the key "city" using my_dict["city"].

# %% [markdown]
# ### **Let us practice some coding question:**

# %% [markdown]
# #### Consider the following list of iconic marvel movie characters. Create two teams of superheroes based on their index position: one team should consist of all the characters located at even index positions, while the other team should consist of all the characters located at odd index positions.
#
# marvel_words = ['Avengers', 'X-Men', 'Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America', 'Wolverine', 'Doctor Strange', 'Namor']

# %%
#Here's the list
marvel_words = ['Avengers', 'X-Men', 'Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America', 'Wolverine', 'Doctor Strange','Namor']

# %%
team1=[marvel_words[0],marvel_words[2],marvel_words[4],marvel_words[6],marvel_words[8],marvel_words[10]] #team odd
team2=[marvel_words[1],marvel_words[3],marvel_words[5],marvel_words[7],marvel_words[9]] #team even

# %%
print(team1)
print(team2)
# Out:
# ['Avengers', 'Spider-Man', 'Hulk', 'Black Widow', 'Wolverine', 'Namor']
# ['X-Men', 'Iron Man', 'Thor', 'Captain America', 'Doctor Strange']

# %% [markdown]
# Seems tiring right? But don't worry. This process can be simplified. We will learn in a while how. 😉

# %% [markdown]
# #### Consider the following list of iconic marvel movie characters. Store the word 'Namor' in a variable and use reverse indexing to reverse it.
#
# marvel_words = ['Avengers', 'X-Men', 'Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America', 'Wolverine', 'Doctor Strange', 'Namor']

# %%
#Here's the list
marvel_words = ['Avengers', 'X-Men', 'Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America', 'Wolverine', 'Doctor Strange','Namor']

# %%
#Reverse the string- Namor
new_word=marvel_words[-1]
namor_reverse=new_word[::-1] #This step might be confusing for you right now. Worry not. We'll explore this technique in a minute.
print(namor_reverse)
# Out:
# romaN

# %% [markdown]
# ### **Activity-1**
#
# ## Solve The Riddle

# %% [markdown]
# 1. A puzzling word "**PYTHAGOREAN**", and I am the **second last letter**. Reveal my position, what is my index?

# %% [markdown]
# #### **Answers**

# %% [markdown]
# 1. **Answer:**The index of the second last letter 'A' in "PYTHAGOREAN" is 9.
#
#   Explanation: Again, remember that indexing in Python starts from 0. So, counting from the end, the second last letter 'A' is at index 9.

# %% [markdown]
# ### **Activity-2**

# %% [markdown]
# #### **Error Spotting**

# %% [markdown]
# 1. Which of the following code snippets contains an error related to indexing?
#
# A)
#
# ```
# # Code Snippet A
# message = "Hello, Python!"
# print(message[13])
# ```
# B)
#
# ```
# # Code Snippet B
# numbers = [1, 2, 3, 4, 5]
# print(numbers[5])
# ```
# C)
#
# ```
# # Code Snippet C
# word = "Python"
# print(word[-6])
# ```
# D)
#
# ```
# # Code Snippet D
# data = (10, 20, 30, 40)
# print(data[4])
# ```

# %% [markdown]
# ##### **Answers**

# %% [markdown]
# 1. **Answer:** B
#
#   Explanation: The code snippet B contains an error related to indexing. In Python, indexing is 0-based, so the last valid index of a list with 5 elements is 4. Trying to access the element at index 5 will result in an "IndexError" as it is out of range.

# %% [markdown]
# ###To Sum up Things
# 🔍👀📊 You've seen that Indexing remains conceptually the same in different data types, although the implementation may differ. In Python, Indexing starts from 0 for the first element and -1 for the last element in a sequence.
#
# 🚫 Not all data types support Indexing. For example, sets are an unordered collection of unique elements in Python and do not support Indexing. If you try to index a set, you will get an error. ⛔
#
# On the other hand, dictionaries in Python can be indexed using keys. When you index a dictionary using a key, you get the corresponding value associated with that key. 🔑
#
# 💻 Overall, Indexing is an essential operation in Python that allows us to access specific elements of data structures. Whether you're working with strings, tuples, sets, or dictionaries, understanding Indexing is crucial to working with data structures more efficiently. 🚀

# %% [markdown]
# ## **Slicing**

# %% [markdown]
# 🔪 Slicing is another common operation in Python that allows us to extract a portion of a sequence, such as a string, tuple, or list. Different types of data structures have different slicing methods, but the general syntax is similar for all of them.

# %% [markdown]
# **The basic syntax for slicing with a step size is as follows:**
#
# `sequence[start:stop:step]`
#
# Here's what each part means:
#
# * start: The index from which the slicing begins (inclusive).
# * stop: The index at which the slicing ends (exclusive).
# * step: The number of elements to skip between each included element.

# %% [markdown]
# ### **Strings**
# 🍴 Let's start with a string, which is a sequence of characters. We can use the slice notation [start:end] to extract a portion of the string. Here's an example:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
my_string = "Hello, world!"
print(my_string[0:5])   # Output: "Hello"
print(my_string[7:])   # Output: "world!"
# Out:
# Hello
# world!

# %% [markdown]
# 👉 In this example,
# * We used slicing to extract the first five characters of the string using my_string[0:5]
# * And the characters after the comma using my_string[7:].

# %% [markdown]
# ## How do we use the **step size**?
# Here we have sliced the whole string but with a step size of 2. So the program would output every second element starting from the first

# %%
my_string[::2]
# Out:
# 'Hlo ol!'

# %% [markdown]
# ####Wondering how we can **reverse** using slicing?
#
# Think about it. reversed string a string starting from the last element of the orignal string and going all the way to the first element. **We can reverse a string by setting the step size to -1**

# %%
my_string[::-1]   #step size of -1 to reverse the string
# Out:
# '!dlrow ,olleH'

# %%
my_string[::-2]   #step size of -2 would reverse the string skipping one element in between
# Out:
# '!lo olH'

# %% [markdown]
# Same concept applies to other data types as well.

# %% [markdown]
# ####🧠 **Brain Teaser** 🧠
# * How can you extract "**yget**" from the string "**strategy**"?

# %% [markdown]
# ### **Solution**:

# %% [markdown]
# my_string[-1:-5:-1]

# %% [markdown]
# ### **Tuples**
# 📦 Tuples are another type of sequence in Python that can be sliced using the slice notation. Here's an example:

# %%
my_tuple = (1, 2, 3, 4, 5)
print(my_tuple[1:3])   # Output: (2, 3)
print(my_tuple[:2])   # Output: (1, 2)
# Out:
# (2, 3)
# (1, 2)

# %% [markdown]
# 👉 In this example, we used slicing to extract a portion of the tuple.
# * The first slice my_tuple[1:3] extracts the second and third elements of the tuple.
# * The second slice my_tuple[:2] extracts the first two elements of the tuple.

# %% [markdown]
# ![TuplesSlice.gif](data:image/gif;base64,...)

# %% [markdown]
# ### **Lists**
# 🍽️ Lists are another type of sequence in Python that can be sliced using the slice notation. Here's an example:

# %%
my_list = [1, 2, 3, 4, 5]
print(my_list[2:])   # Output: [3, 4, 5]
print(my_list[:3])   # Output: [1, 2, 3]
print(my_list[1:4:2])   # Output: [2, 4]
# Out:
# [3, 4, 5]
# [1, 2, 3]
# [2, 4]

# %% [markdown]
# 👉 In this example, we used slicing to extract a portion of the list.
# * The first slice my_list[2:] extracts all elements after the second element of the list.
# * The second slice my_list[:3] extracts the first three elements of the list.
# * The third slice my_list[1:4:2] extracts every second element between the second and fifth elements of the list.

# %% [markdown]
# ### **Sets**
# 👥 Sets are an unordered collection of unique elements in Python, and they do not support slicing, since they don't support indexing.

# %%
my_set = {1, 2, 3, 4, 5}

print(my_set[1:3])   # Error: 'set' object is not subscriptable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-efd406a3cddf> in <cell line: 3>()
#       1 my_set = {1, 2, 3, 4, 5}
#       2
# ----> 3 print(my_set[1:3])   # Error: 'set' object is not subscriptable
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ❌ In this example, we tried to slice the set using my_set[1:3], but we got an error because sets do not support slicing.

# %% [markdown]
# ### **Dictionary**

# %% [markdown]
# 📚 Dictionaries are a collection of key-value pairs in Python, and we can slice a dictionary using a list of keys. However, unlike lists or tuples, slicing with dictionaries is not done using the : operator.
#
# Instead, you can use the dict() constructor to create a new dictionary from a slice of an existing dictionary.
#
# We will explore this when we focus on dictionaries later.

# %% [markdown]
# ##**Indexing & Slicing Dictionaries.**
#
# Indexing in a dictionary is done using the keys. You can access the value associated with a particular key by using the square bracket notation with the key inside the brackets. For example:

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
value_a = my_dict['a']  # returns 1
value_a
# Out:
# 1

# %% [markdown]
# Slicing a dictionary is not possible since dictionaries are unordered and do not support slicing. However, you can get a subset of a dictionary by creating a new dictionary with only the desired keys. You can use the dict() constructor and a list comprehension to achieve this. For example:

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
subset_dict = dict((key, my_dict[key]) for key in ['a', 'c']) #This is an advanced technique which you'll explore later. Don't worry if you don't understand this yet.
# returns {'a': 1, 'c': 3}
subset_dict
# Out:
# {'a': 1, 'c': 3}

# %% [markdown]
# This creates a new dictionary subset_dict that contains only the key-value pairs for the keys 'a' and 'c'.

# %% [markdown]
# We have utilized list comprehension and iterative loops to execute slicing. However, don't worry if you're not yet familiar with these methods as you will learn about them later.

# %% [markdown]
# ### **Let us practice hands-on coding question:**

# %% [markdown]
# #### Here's a list of iconic marvel movie characters:
#
# marvel_words = ['Avengers', 'X-Men', 'Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America', 'Wolverine', 'Doctor Strange', 'Namor']
#
# Write a code to print these characters:
#
# 'Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America'

# %%
#Here's the list
marvel_words = ['Avengers', 'X-Men', 'Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America', 'Wolverine', 'Doctor Strange','Namor']

# %%
#Slicing list
new_marvel=marvel_words[2:8]
print(new_marvel)
# Out:
# ['Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America']

# %% [markdown]
# #### Given a list of iconic marvel movie characters. Store the word 'Spider-Man' in a new variable, and slice the word 'Spider' from it.
#
# marvel_words = ['Avengers', 'X-Men', 'Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America', 'Wolverine', 'Doctor Strange', 'Namor']

# %%
#Here's the list
marvel_words = ['Avengers', 'X-Men', 'Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America', 'Wolverine', 'Doctor Strange','Namor']

# %%
#Store the word 'Spider-Man' in a new variable

new_word= new_marvel[0]
spider_slice=new_word[0:6]
print(spider_slice)
# Out:
# Spider

# %% [markdown]
# ### **Activity-3**

# %% [markdown]
# #### **True or False**

# %% [markdown]
# Statement -1: Slicing is a method used exclusively with lists in Python to extract a sequence of elements from the list.
# True or False?
#
# Statement-2: Slicing can be performed on tuples in Python to create a new tuple containing the selected elements from the original tuple.
# True or False?
#
# Statement-3: Slicing is not applicable to dictionaries in Python, as they are unordered collections of key-value pairs.
# True or False?
#
# Statement-4: In Python, the start index of a slice is inclusive, while the end index is exclusive.
# True or False?
#
# Statement-5: Slicing with negative indices is not possible in Python, as it leads to ambiguous results.
# True or False?

# %% [markdown]
# ##### **Answers**

# %% [markdown]
# Statement 1:
# **Answer:** False
#
#   Explanation: Slicing is not limited to lists; it can also be used with tuples and strings in Python. It is a versatile method that allows you to extract a portion of a sequence-like data structure, including lists, tuples, and strings.
#
# Statement 2:
# **Answer:** True
#
#   Explanation: Slicing can indeed be performed on tuples in Python. Like lists, slicing allows you to create a new tuple that contains the selected elements from the original tuple. This is because tuples, like lists, are also sequence-like data structures.
#
# Statement 3:
# **Answer:** True
#
#   Explanation: Slicing is applicable to lists, tuples, and strings but not dictionaries. Dictionaries are unordered collections of key-value pairs, and they do not support slicing operations.
#
# Statement 4:
# **Answer:** True
#
#   Explanation: In Python, the start index of a slice is inclusive, meaning the element at the start index is included in the slice. However, the end index is exclusive, meaning the element at the end index is not included in the slice.
#
# Statement 5:
# **Answer:** False
#
#   Explanation: Slicing with negative indices is possible in Python. Negative indices count elements from the end of the data structure. For example, -1 refers to the last element, -2 refers to the second last element, and so on.

# %% [markdown]
# ### To Sum Things Up
#
# 🔍👀📊 Similarly to indexing, slicing is a way of accessing specific elements in data structures, but instead of retrieving a single element, it retrieves a sequence of elements.
#
# 🗂️ In Python, slicing allows you to extract a portion of a sequence or collection. You can specify a range of indices to create a slice, with the format [start:stop:step]. The start index is inclusive, while the stop index is exclusive.
#
# 🚫 Not all data types support slicing. For example, sets do not support slicing as they are unordered collections of unique elements.
#
# 🔑 Slicing works with most sequences in Python, such as strings, lists, and tuples. It allows you to extract substrings, sublists, or subtuples.
#
# 💻 Overall, understanding slicing is important to efficiently manipulate sequences in Python. Whether you're working with strings, lists, tuples, or other sequences, knowing how to slice them can make your code more concise and readable. 🚀

# %% [markdown]
# ##You made it to the end!! 🎉🎉🎉
#
# Equipped with the knowledge of indexing and slicing, you're all set to achieve great things in the world of Python. You can now efficiently access specific elements or portions of data structures like strings, lists, tuples, and dictionaries. With these skills, you'll be able to write more concise, readable, and efficient code that can handle complex data manipulation tasks. So go ahead and explore the vast world of Python with confidence, and unlock its full potential! 🚀

# %% [markdown]
# # **✅ Summary ✅**

# %% [markdown]
# ##**What did you Learn?**
#
# 1. Indexing and slicing are techniques that allow efficient manipulation of data types such as strings, lists, tuples, and dictionaries.
# 2. Indexing refers to accessing a single element in a data type by its position, while slicing allows accessing a range of elements in a data type.
# 3. Best practices for working with indexing and slicing data types include using descriptive variable names, ensuring code efficiency, and avoiding potential errors such as index errors and exceeding the bounds of the data type when slicing.
# 4. The syntax for indexing and slicing varies slightly based on the data type, but the method remains conceptually the same.
# 5. Overall, indexing and slicing data types are essential techniques in Python programming that can lead to more efficient and reliable software solutions.

# %% [markdown]
# ###**Best Practices/Tips**
#
# 1. Use descriptive variable names: When defining variables, use descriptive names that make it clear what the variable represents. This makes the code easier to understand and maintain.
# 2. Ensure code efficiency: Indexing and slicing operations can be computationally expensive, especially when working with large data sets. Ensure that your code is efficient by minimizing the number of operations needed to achieve the desired result.
# 3. Avoid index errors: Be mindful of potential index errors, which can occur when trying to access an element that does not exist in a data type. Always ensure that the index value is within the bounds of the data type.
# 4. Understand syntax: The syntax for indexing and slicing varies based on the data type being used. Understand the syntax for each data type to avoid syntax errors.
# 5. Consider readability: Use line breaks and indentations to make your code more readable. This can help to avoid errors and make it easier to understand what the code is doing.
# 6. Test your code: Always test your code thoroughly to ensure that it is working as expected. This includes testing edge cases and error handling.

# %% [markdown]
# ###**Shortcomings**
#
# 1. Inefficient for large data sets: Indexing and slicing operations can be computationally expensive, especially when working with large data sets. This can slow down the performance of your code and impact its efficiency.
# 2. Memory usage: When using slicing to extract a subset of elements from a larger data type, a new object is created in memory. This can increase the memory usage of your program, especially when working with large data sets.
# 3. Not applicable for all data types: Indexing and slicing are not applicable for all data types in Python. For example, you cannot use these techniques on sets or frozen sets.
# 4. Can lead to index errors: It is important to ensure that the index value is within the bounds of the data type when using indexing and slicing. Otherwise, you may encounter index errors that can cause your code to fail.
# 5. Syntax can be confusing: The syntax for indexing and slicing can be confusing, especially for developers who are new to Python. It is important to understand the syntax for each data type to avoid syntax errors.

# %% [markdown]
# In summary, indexing and slicing act as the fundamental tools that empower you to interact with data types and apply operators effectively. They enable you to extract, modify, and combine elements, unlocking the full potential of the operators and bridging the gap between your code and the desired data transformations. So, embrace the power of indexing and slicing, and let them guide you to new horizons in your Python programming journey! 🔍🚀🌟

# %% [markdown]
# # **➕ Enhance your Knowledge ➕**

# %% [markdown]
# ##**Mnemonic**
#
# Mnemonics are texts or devices that helps you to remember a concept. Here's a mnemonic to help you remember Indexing and Slicing

# %% [markdown]
# Codehacker was a software development company that used Python as one of its primary programming languages. They understood the importance of indexing and slicing data types in Python to manipulate data efficiently.
# The development team at Codehacker spent time learning about indexing and slicing data types in Python, such as strings, lists, tuples, and dictionaries. They understood that indexing was the process of accessing an element in a data type by its position, while slicing was the process of accessing a range of elements in a data type.
# The team used indexing and slicing to manipulate data in various ways. For example, they used indexing to access a specific character in a string, and they used slicing to extract a substring from a string. They also used indexing and slicing to access specific elements in lists and tuples and to extract a subset of elements from a larger list or tuple.
# The team also learned about the best practices for working with indexing and slicing in Python. They used descriptive variable names to make their code more readable, and they used the appropriate syntax to ensure that their code was efficient and accurate.
# As the team worked on various projects, they faced several challenges related to indexing and slicing in Python. For example, they had to deal with index errors when trying to access an element that did not exist in a data type, and they had to be careful when slicing data types to ensure that they did not exceed the bounds of the data type.
# However, by understanding indexing and slicing data types in Python and applying best practices, Codehacker was able to create efficient, reliable, and scalable software solutions for their clients. They documented their code and used comments to explain their indexing and slicing techniques, making it easier for others to understand and maintain their code.
# In the end, Codehacker was successful in creating innovative solutions for their clients, thanks to their understanding of indexing and slicing data types in Python.

# %% [markdown]
# ## **Additional Reading: Indexing & Slicing📖🔍🔪🐍**

# %% [markdown]
# 🤔Did you know that Python's indexing and slicing capabilities go far beyond just accessing elements?

# %% [markdown]
# **Negative Indexing: Unlocking the Secrets of Reversed Slicing 🔍🔓** 🔍🔓
#   - Negative indexing is not limited to accessing elements from the end of a sequence; it also allows you to perform reversed slicing effortlessly! 😲🔙 By using negative indices with slicing, you can quickly extract a reversed subset of your data. Behold:

# %%
fruits = ["apple", "banana", "cherry", "date", "elderberry"]

# Reverse the list using negative stride
reversed_fruits = fruits[::-1]
print(reversed_fruits)  # Output: ['elderberry', 'date', 'cherry', 'banana', 'apple']

# %% [markdown]
# **Multi-dimensional Slicing: Navigating in the Matrix 🌌🔢**
#   - Python's slicing doesn't stop at one-dimensional sequences; you can masterfully slice through multi-dimensional data structures like a seasoned explorer! 🧭🗺️ Let's delve into the world of 2D lists (matrices) and see how slicing works:

# %%
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# Extract the second row using simple indexing
row_2 = matrix[1]
print(row_2)  # Output: [4, 5, 6]

# Extract the second column using list comprehension
column_2 = [row[1] for row in matrix]
print(column_2)  # Output: [2, 5, 8]

# Extract a 2x2 submatrix from the main matrix
submatrix = [row[1:3] for row in matrix[1:3]]
print(submatrix)  # Output: [[5, 6], [8, 9]]

# %% [markdown]
# **Slice Assignment: Altering Data with Precision 🔧🛠️**
#   - Did you know that you can use slicing to modify portions of your data in place? Python allows slice assignment, enabling you to replace specific elements without creating a new list or string! 🔄🔠

# %%
sentence = "Hello, world!"

# Replace "world" with "Python" using slice assignment
sentence_chars = list(sentence)  # Convert the string to a list for slice assignment
sentence_chars[7:12] = "Python"
new_sentence = "".join(sentence_chars)
print(new_sentence)  # Output: "Hello, Python!"

# %% [markdown]
# # **Additional Resources**

# %% [markdown]
# - [https://towardsdatascience.com/the-basics-of-indexing-and-slicing-python-lists-2d12c90a94cf](https://towardsdatascience.com/the-basics-of-indexing-and-slicing-python-lists-2d12c90a94cf)

# %% [markdown]
# # **Try it yourself📃**📟
#
# Are you ready to put your coding skills to the test and gain practical knowledge? We have some exciting coding questions waiting for you to solve! 🚀
#
# Your task is to attempt the coding questions associated with this lesson. These challenges have been thoughtfully designed to reinforce your understanding of the concepts covered in the course. You can find them in your dashboard under this lesson.
#
# Don't be shy! Share your findings, experiences, and any insights you gained while tackling these coding questions on the AlmaBetter community platform. Engage in discussions, help each other out, and celebrate your victories together!
#
# Remember, coding is not just about learning theory; it's about applying that knowledge to solve real-world problems. So, dive in, experiment, and have fun while honing your coding skills!
# Let's learn, grow, and inspire each other as a vibrant community of passionate learners. Happy coding! 💻 😊

# %% [markdown]
# ## **Task 1:**

# %% [markdown]
# #### **🔴 Go to the AlmaBetter IDE on the Practice Tab and solve the coding questions specific to the lesson.🔴**

# %% [markdown]
# In Dashboard, go to Practice Tab and solve the below problems:
#
# **Problem 1:** Product of list elements
#
# **Problem 2:** Match paranthesis
#
# **Problem 3:** Index of matching parenthesis

# %% [markdown]
# ## **Task 2:**

# %% [markdown]
# #### **🔴 Explain the solution of any one problem in your Cohort in the AlmaBetter Community Platform.🔴**
