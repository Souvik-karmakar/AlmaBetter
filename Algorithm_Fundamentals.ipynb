# %% [markdown]
# # **Session Flow:**

# %% [markdown]
# 👨🏻‍🎓 Learning Objective:
#
# * Introduction
# * Theme
# * Primary Goals
#
#
# 🧑Introduction to Algorithms:
#
# * Start with an overview of what algorithms are and their significance in computer science and programming.
#
# * Understand the characteristics of good algorithms, such as correctness, efficiency, and simplicity.
#
# ✍ Big O Notation:
#
# * Learn about Big O notation, which describes the time complexity of algorithms.
#
# * Understand how to analyze the efficiency of algorithms in terms of their worst-case, best-case, and average-case scenarios.
#
# 📚 Data Structures:
#
# * Familiarize yourself with fundamental data structures like arrays, linked lists, stacks, queues, trees, and graphs.
#
# * Learn about their basic operations, advantages, and use cases.
#
#
# 📑 Sorting Algorithms:
#
# * Explore different sorting algorithms, including bubble sort, selection sort, insertion sort, merge sort, quicksort, and heap sort.
#
# * Understand the working principles and time complexities of each sorting algorithm.
# * Activity: Fill in the Blanks
#
# 🔍 Searching Algorithms:
#
# * Study various searching algorithms, such as linear search, binary search, and depth-first search (DFS) or breadth-first search (BFS) for graphs.
#
# * Understand the time complexities and applications of each algorithm.
# * Activity: Guess the Word
#
# 📝 Summary
#
# * What did we learn?
# * Shortcomings & Challenges
# * Best Practices & Tips
#
# 🔗 Enhance your Knowledge
#
# * Mnemonic
# * Additional Resources
#
# 🔍 Try it Yourself
#
# * Activities
# * Social Engagement

# %% [markdown]
# # **👨🏻‍🎓 Learning Objective 👨🏻‍🎓**

# %% [markdown]
# ##**Introduction**
#
# Algorithms are a fundamental part of computer science and programming. They are sets of instructions that a computer follows to solve a specific problem or accomplish a specific task. In this lesson, we will explore the basics of algorithms and how they work in Python.
# 🤖🐍
#
# We will explore algorithms using Python, a popular programming language. Python has a wide range of built-in functions that can be used to implement algorithms quickly and efficiently.
# 🔍 We will cover various topics, including sorting and searching algorithms, graph algorithms, dynamic programming, and more.
# 🎓 By the end of this lesson, you will have a basic understanding of how algorithms work and how to implement them in Python. Are you ready to start your journey into the world of algorithms? Let's get started!
#
#
#
# **Focus- Algorithms, Searching Algorithms, Sorting Algorithms**
#
#
# ##**Theme**
# Algorithm fundamentals are the backbone of efficient and effective problem-solving in computer science and programming. 💻They provide a systematic approach to breaking down complex tasks into step-by-step procedures, optimizing resource usage, and ensuring scalability. Proficiency in algorithms enables programmers to write faster and more responsive code, design better software systems, and excel in competitive programming and coding interviews 🛠️🔍
#
#
#
#
#
# ##**Primary Goals**
#
# 📚🔍👨‍💻 Let's start by setting some primary goals to help you get started with learning Arrays and Strings in Python using libraries that make your coding life easier. 🤩
#
# * 🤖 Understand the basic concept of algorithms and their importance in problem-solving.
# * 🔍 Explore the different types of algorithms, including sorting, searching, graph, and dynamic programming algorithms.
# * 🧐 Learn the definition and implementation of common algorithms like linear and binary searches.
# * 🎯 Master sorting algorithms like bubble sort, selection sort, insertion sort, and quicksort, and learn when to use each one.
# * 🤓 Develop the skills to analyze an algorithm's time and space complexity and understand how it affects program efficiency.
# * 🤝 Work on collaborative activities that involve implementing algorithms in Python and sharing feedback and ideas with peers.
#
# Remember, learning Arrays and Strings in Python is an ongoing process, and it's okay to take it one step at a time. With dedication and practice, you'll soon become proficient in working with these powerful data structures. 🤝

# %% [markdown]
# # **📖 Learning Material 📖**

# %% [markdown]
# 👋 Hey there!
#
# 👨‍🏫 Today's lesson is all about algorithms.

# %% [markdown]
# ![alfgo.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 🤖 An algorithm is like a 📃 recipe for a computer program. It's a set of well-defined instructions 👨‍🏫 or a step-by-step procedure used to solve a problem or perform a specific task. It is a mathematical concept that is widely used in computer science and various other fields to automate processes. 🖥️
#
# 🔍 In computing, an algorithm is like a treasure map 🗾, showing the path 🛣 to accomplish a particular task. These instructions can be written in various programming languages and are executed by a computer. 📝

# %% [markdown]
# 💻 Algorithms are like secret weapons in the world of computing, used in various applications, including search engines 🔍, cryptography 🔐, artificial intelligence 🤖, data analysis 📊, and many others.
#
#  They are essential in the development of software and other computer applications. 💡

# %% [markdown]
# 📊 Algorithms can be classified into several categories based on their design and functionality, including 📊 Sorting algorithms - used to sort data in a specific order, 🔍 Search algorithms - used to find specific data in a dataset.
#
# There are also advanced algorithms like 🔢 Numerical algorithms - used for numerical analysis and 📊🧮 calculations, and Machine learning algorithms - used to learn from data and make 📈 predictions or 📊🧠 decisions based on that data.

# %% [markdown]
# Algorithms are like superheroes 🦸‍♂️🦸‍♀️ of computing, and are used in various applications to automate processes and solve problems efficiently. They can be like a magical wand 🧙‍♀️ that makes complex tasks simple and manageable. 🚀

# %% [markdown]
# 🔍 Sorting and searching algorithms are two 🌟fundamental and widely used🌟 algorithms in computer science. Sorting algorithms are used to arrange a set of data in a specific order, while searching algorithms are used to find a specific piece of data in a dataset. Both of these algorithms have numerous applications in computer science and beyond. 🔍
#
# 🧐 There are many sorting and searching algorithms available, each with its own advantages and disadvantages.
#
# 💭 In the following explanation, we will discuss one of the most commonly used sorting algorithms, bubble sort 🧼, and how it works.
#
#  We will also discuss a common searching algorithm, linear search 🔎, and how it is used to efficiently search a sorted list.

# %% [markdown]
# ## **Sorting Algorithms ◀ ▶**
# ___
# ___

# %% [markdown]
# 🧹 Sorting is the process of arranging items or elements in a particular order, such as ascending or descending order, based on a certain criteria, such as numerical or alphabetical order. The goal of sorting is to make it easier to search 🔍, access 🔑, and analyze 🤔 data by organizing it in a structured way. Sorting is used in various applications, such as organizing lists 📝 of contacts, arranging files 📂 in a file system, sorting search results by relevance 🎯, and more.
#
# There are several sorting algorithms 🤖 that can be used to sort data, each with its own advantages and disadvantages in terms of time complexity ⏰, space complexity 🚀, and performance 💪

# %% [markdown]
# Some real-life examples of sorting include:
#
# 📞📖 Telephone directories: These are books that contain telephone numbers and addresses of people sorted in alphabetical order.
#
# 📖🔍 Dictionaries: These are collections of words with their meanings sorted in alphabetical order.
#
# 📱📝 Contact lists: These are lists of contact numbers of people on a mobile phone sorted in alphabetical order.

# %% [markdown]
# In sorting, there are different types of orders that can be applied to a set of values. These include:
#
# **Increasing Order:** This type of order is when every successive element is
# greater than its previous element. For example, the sequence 1, 2, 3, 4, 5 is in increasing order because each number is greater than the one before it.
#
# **Decreasing Order:** This type of order is when every successive element is less than its previous element. For example, the sequence 5, 4, 3, 2, 1 is in decreasing order because each number is less than the one before it.
#
# **Non-Increasing Order:** This type of order occurs when every ith element present in the sequence is less than or equal to its (i-1)th element. This order occurs whenever there are numbers that are being repeated. For example, the sequence 5, 4, 4, 3, 2, 1 has two 4s and is in non-increasing order because each number is lesser than or equal to the one before it.
#
# **Non-decreasing order:** A set of values is said to be in non-decreasing order if each ith element in the sequence is greater than or equal to its (i-1)th element. This order also occurs whenever there are numbers that are being repeated. For example, 1, 2, 2, 3, 4, 5 has two 2s and is in non-decreasing order.

# %% [markdown]
# 🤔 Understanding the different types of orders is crucial when selecting a sorting algorithm for a given set of data. 💡💻 Some algorithms work better for specific orders than others, and selecting the right one can enhance efficiency and reduce computational time. ⏱️👌

# %% [markdown]
# ![sort.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 👨‍💻 Let's dive into the world of sorting algorithms and discover some of the most commonly used ones in computer science. 🧐 We'll also learn how to implement them in Python, so get ready to sharpen your programming skills! 💻

# %% [markdown]
# ##🎁**Bonus Tool**🎁

# %% [markdown]
# You may use the following tool to visualize and understand different types of sorting algorithms:
#
# https://www.cs.usfca.edu/~galles/visualization/ComparisonSort.html.
#
# This tool can be helpful in learning the step-by-step process of how sorting algorithms work and how they differ from each other.

# %% [markdown]
# ## **Bubble Sort**

# %% [markdown]
# ![Bubble_sort_animation.gif](data:image/gif;base64,...)

# %% [markdown]
#  Bubble Sort is a simple sorting algorithm that works by repeatedly comparing two adjacent elements and swapping them if they are in the wrong order. It is also known as the sinking sort. 🌊
#
# 👥 It can be visualized as a queue where people arrange themselves by swapping with each other so that they all can stand in ascending order of their heights. 👫
#
# ⏰ Bubble Sort has a time complexity of O(n^2) in the average and worst cases scenarios and O(n) in the best-case scenario.
#
# 🔄 We compare two adjacent elements and see if their order is wrong, if the order is wrong we swap them. (i.e arr[i] > arr[j] for 1 <= i < j <= s; where s is the size of the array, if array is to be in ascending order, and vice-versa).

# %% [markdown]
# Let's consider an example to understand how bubble sort works. Suppose we have an unsorted list of integers: [5, 2, 7, 3, 1, 8, 6, 4].

# %% [markdown]
# First Pass:
#
# Starting from the first element of the list, we compare the first two elements (5 and 2). Since 2 is smaller than 5, we swap them to get [2, 5, 7, 3, 1, 8, 6, 4]. We then compare the next two elements (5 and 7), which are already in the correct order, so we move on to the next pair. We continue this process until we reach the end of the list, which gives us [2, 5, 3, 1, 7, 6, 4, 8]. Here, the largest element (8) has "bubbled" to the end of the list.
#
# Second Pass:
#
# We start again from the first element and compare the first two elements (2 and 5), which are already in the correct order. We then compare the next two elements (5 and 3) and swap them to get [2, 3, 5, 1, 7, 6, 4, 8]. We continue this process until we reach the end of the list, which gives us [2, 3, 1, 5, 6, 4, 7, 8]. Here, the second-largest element (7) has "bubbled" to the second-to-last position.
#
# Third Pass:
#
# We start again from the first element and compare the first two elements (2 and 3), which are already in the correct order. We then compare the next two elements (3 and 1) and swap them to get [2, 1, 3, 5, 6, 4, 7, 8]. We continue this process until we reach the end of the list, which gives us [2, 1, 3, 5, 4, 6, 7, 8]. Here, the third-largest element (6) has "bubbled" to the third-to-last position.
#
# Fourth Pass:
#
#
# We start again from the first element and compare the first two elements (2 and 1) and swap them to get [1, 2, 3, 5, 4, 6, 7, 8]. We continue this process until we reach the end of the list, which gives us [1, 2, 3, 4, 5, 6, 7, 8]. Here, the list is fully sorted in ascending order.

# %% [markdown]
# Here is the implemention of above example:

# %%
def bubble_sort(arr):
    n = len(arr)
    # Traverse through all array elements
    for i in range(n):
        # Last i elements are already in place
        for j in range(0, n-i-1):
            # Traverse the array from 0 to n-i-1
            # Swap if the element found is greater than the next element
            if arr[j] > arr[j+1] :
                arr[j], arr[j+1] = arr[j+1], arr[j]


arr = [5, 2, 7, 3, 1, 8, 6, 4]

bubble_sort(arr)
print("Sorted array is:")
for i in range(len(arr)):
    print("%d" %arr[i])
# Out:
# Sorted array is:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %% [markdown]
# This shows that the bubble sort algorithm has successfully sorted the input array.

# %% [markdown]
# ## **🤔 Do You Know 🤔**

# %% [markdown]
# 📝 Hey students! While learning sorting algorithms is important, in real-life scenarios, you don't have to implement them yourself! 😅 Most programming languages come with built-in functions like sort() that make your life a lot easier. These functions are optimized for efficiency and save you the trouble of writing and debugging lengthy sorting algorithms. 🙌
#
# For example, let's say you have a list of numbers that you want to sort in ascending order. You can use the sort() function in Python to do this easily:

# %%
numbers = [4, 2, 8, 5, 1, 3, 7, 6]
numbers.sort()
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# As you can see, the sort() function has sorted the list in ascending order for us. So, the next time you need to sort a list, don't forget to use the built-in sort() function! 👍

# %% [markdown]
# ## 🔍 **Activity: Fill in the Blanks**

# %% [markdown]
# Fill in the blanks to complete the description of Bubble Sort:
#
# Bubble Sort is a simple ________-based sorting algorithm. It repeatedly steps through the list, compares adjacent elements, and swaps them if they are in the ________ order. This process is repeated until the entire list becomes _________. The algorithm gets its name from the way smaller elements "bubble" to the ________ of the list with each iteration.

# %% [markdown]
# ### **Answer:**

# %% [markdown]
# Bubble Sort is a simple comparison-based sorting algorithm.
# It repeatedly steps through the list, compares adjacent elements, and swaps them if they are in the wrong order.
# This process is repeated until the entire list becomes sorted.
# The algorithm gets its name from the way smaller elements "bubble" to the beginning of the list with each iteration.
#
#
# Explanation:
#
# Bubble Sort is a basic sorting algorithm that compares adjacent elements in the list and swaps them if they are in the wrong order. The process of comparison and swapping continues until the entire list becomes sorted. In each iteration, the smaller elements "bubble" to the beginning of the list, leading to its name "Bubble Sort." While Bubble Sort is straightforward, it is not the most efficient sorting algorithm, especially for large lists, as it has an average and worst-case time complexity of O(n^2).

# %% [markdown]
# ## **Searching Algorithms 🔎 🔍**
# ___
# ___

# %% [markdown]
# 🔍 Searching is the process of finding a specific item or a set of items within a collection of data. It is a fundamental operation in computer science and is used in a wide variety of applications, such as information retrieval, data mining, and artificial intelligence. 🧐

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 🔎 Searching algorithms are methods for finding items within a collection of data. They are used to perform the searching operation efficiently and with a minimum of wasted effort. There are many different searching algorithms, each with its own strengths and weaknesses, and the choice of algorithm depends on the specific needs and characteristics of the data being searched. 🔍💻🔬

# %% [markdown]
# 🔍 Searching algorithms have numerous applications in 🖥️ computer science and beyond.
#
# Here are a few examples:
#
# 📚 **Information retrieval:** Searching algorithms are used extensively in information retrieval systems such as search engines. When a user enters a search query, the system uses a searching algorithm to match the query with the relevant documents in its database.
#
# ⛏️ **Data mining:** Data mining is the process of discovering patterns and relationships in large data sets. Searching algorithms such as association rule mining and clustering are used to analyze the data and extract valuable insights.
#
# 🤖 **Artificial intelligence:** Searching algorithms are used in many artificial intelligence applications, such as game playing and route planning. In game playing, searching algorithms are used to find the best move to make given the current state of the game. In route planning, searching algorithms are used to find the shortest path between two points on a map.
#
# 💾 **Database management:** Searching algorithms are used to efficiently search and retrieve data from databases. Indexing techniques such as B-trees and hash tables are commonly used to speed up the searching process.
#
# 🧬 **Genetics and bioinformatics:** Searching algorithms are used to analyze genetic data and identify patterns that may be associated with diseases or other traits. For example, the BLAST algorithm is used to search for similarities between DNA sequences.
#
# 💰 **Finance and economics:** Searching algorithms are used in financial and economic analysis to search for patterns in stock prices and other financial data. These patterns can be used to make predictions and inform investment decisions.

# %% [markdown]
# 🔍💻🤿 So now, let's dive deep into some of the most commonly used Searching algorithms 💡🔎

# %% [markdown]
# ##🎁**Bonus Tool**🎁

# %% [markdown]
# If you are learning about searching algorithms and finding it hard to understand the concepts, don't worry! There is a tool available to help you visualize different types of searching algorithms. You can use this tool to get a better understanding of how these algorithms work and how they can be implemented in real-world scenarios. Check out this website, https://www.cs.usfca.edu/~galles/visualization/Search.html, where you can see the step-by-step visualization of various searching algorithms such as linear search, binary search, and more.
#
# Best of luck with your studies!
#
# 🔍📈💻

# %% [markdown]
# ## **Linear Search**

# %% [markdown]
# 🔍 Linear search is a basic searching algorithm that works by sequentially checking each element in a collection of data until a match is found or the end of the collection is reached. It's also sometimes called a "sequential search" or "brute force search".

# %% [markdown]
# ![cakesearch.gif](data:image/gif;base64,...)

# %% [markdown]
# Here's how it works:
#
# 1. Start at the beginning of the data set.
# 2. Compare the first element with the target element being searched for.
# 3. If the target is found, return the index of the element.
# 4. If the target is not found, move to the next element in the data set and repeat steps 2 and 3 until the target is found or the end of the data set is reached

# %% [markdown]
# Here's an example code in Python for linear search:

# %%
# Define the linear search function that takes a list of data and a target value
def linear_search(data, target):
    # Loop over each element in the list of data
    for i in range(len(data)):
        # If the current element is equal to the target value, return the index of the element
        if data[i] == target:
            return i
    # If the target value is not found in the list of data, return -1
    return -1

# Get user input for the list of data and the target value
data = list(map(int, input("Enter the list of data, separated by spaces: ").split()))
target = int(input("Enter the target value: "))

# Call the linear search function with the list of data and the target value
index = linear_search(data, target)

# If the target value is found in the list of data, print a message with the index of the element
if index != -1:
    print(f"Target {target} found at index {index}")
# If the target value is not found in the list of data, print a message indicating it was not found
else:
    print(f"Target {target} not found in data")
# Out:
# Enter the list of data, separated by spaces: 1 2 3 4 5 6 8 9
# Enter the target value: 2
# Target 2 found at index 1

# %% [markdown]
# In this example, the linear_search function takes two arguments: data, which is the list of values to search, and target, which is the value we are searching for. The function uses a for loop to iterate through each element of the list. If the element matches the target, the function returns the index of the element. If no match is found, the function returns -1.

# %% [markdown]
# Linear search 🔍 is a simple and straightforward algorithm, but it can be slow ⏳ for large data sets.  Its time complexity is O(n), where n is the size of the data set. For this reason, it's typically only used for small data sets or for cases where the data is unsorted and random access to elements is not possible. 🤔
#
# For larger data sets, more efficient searching algorithms such as binary search or hash tables are often used instead.
#
# ---

# %% [markdown]
# ## **🤔Do You Know 🤔**

# %% [markdown]
# 🔍👨‍🎓 As students learn about searching algorithms, it can be tempting to try to implement complex algorithms from scratch in real-life scenarios. However, it's important to remember that programming languages provide built-in functions and loops to make our lives easier. 🙌 Instead of reinventing the wheel, students can use these functions and loops to implement efficient searching algorithms quickly and easily.
#
# For example, the in keyword in Python can be used to check if an element is present in a list or not. Similarly, the index method in Python can be used to find the index of the first occurrence of an element in a list.
#
# Here's an example of how to use the in keyword to check if an element is present in a list:

# %%
my_list = [1, 2, 3, 4, 5]
if 3 in my_list:
    print("Element found!")
else:
    print("Element not found.")
# Out:
# Element found!

# %% [markdown]
# And here's an example of how to use the index method to find the index of the first occurrence of an element in a list:

# %%
my_list = [1, 2, 3, 4, 5]
index_of_three = my_list.index(3)
print("Index of 3:", index_of_three)
# Out:
# Index of 3: 2

# %% [markdown]
# 🔍 Using built-in functions and loops can save students a lot of time and effort, and make their code more efficient and readable. However, it's still important to understand the underlying principles of searching algorithms and how they work. By using these tools in conjunction with a solid understanding of algorithms, students can become more effective programmers and problem solvers.

# %% [markdown]
# ## 🔍 **Activity: Guess the Word**

# %% [markdown]
# **Riddle 1:**
#
# I am a sorting method, simple and slow,
#
# Comparing elements in a row.
#
# If they're out of order, I'll make a swap,
#
# Moving the largest to the top.
#
# What sorting algorithm am I?
#
#
# **Riddle 2:**
#
# In a list, I'll seek and find,
#
# A target value that's on my mind.
#
# One by one, I'll scan each element,
#
# Until I reach the desired attainment.
#
# What searching method am I?

# %% [markdown]
# ### **Answers:**

# %% [markdown]
# Answer 1:
# Bubble Sort
#
# Explanation:
# Bubble Sort is a simple sorting algorithm that repeatedly steps through the list, compares adjacent elements, and swaps them if they are in the wrong order. In each iteration, the largest element "bubbles" to the top of the list.
#
# Answer 2:
# Linear Search
#
# Explanation:
# Linear Search is a searching algorithm that scans each element in a list one by one until it finds the target value or reaches the end of the list. It is a simple but potentially slow searching method for unsorted or small-sized lists.

# %% [markdown]
# # **✅ Summary ✅**

# %% [markdown]
# ##**What did you Learn?**
# 🤖💡🐍 Algorithm Fundamentals in Python:
#
# * 📚 Algorithms are a set of instructions used to solve a problem or complete a task.
#
# * 🧐 Types of algorithms include Brute Force Algorithm, Divide and Conquer Algorithm, Dynamic Programming Algorithm, Greedy Algorithm, and Backtracking Algorithm.
#
# * 🤔 Searching algorithms include Linear Search Algorithms and Binary Search algorithms.
#
# * 💭 Sorting algorithms include Bubble Sort Algorithm, Selection Sort Algorithm, Insertion Sort Algorithm, Merge Sort Algorithm, and Quick Sort Algorithm.
#
# * 🧑‍💻 To practice algorithm implementation, try coding one of these searching or sorting algorithms in Python and test it out with sample data. You can use Python's built-in functions or libraries to help with your implementation.
#
# ###**Best Practices/Tips**
#
# 🤖💡🐍 Algorithm Fundamentals in Python Best Practices/Tips:
#
# 👉 Keep it simple: When developing algorithms, strive for simplicity. Complex algorithms can be difficult to understand, debug, and maintain.
#
# 👉 Pseudocode first: Write your algorithm in pseudocode first before coding it in Python. Pseudocode allows you to focus on the logic of your algorithm without getting bogged down in syntax.
#
# 👉 Test frequently: Test your algorithm frequently with sample data to ensure it's working correctly. Start with small inputs and work your way up to larger ones.
#
# 👉 Use built-in functions and libraries: Python has many built-in functions and libraries that can help you implement algorithms efficiently. Use them to your advantage.
#
# 👉 Optimize for efficiency: When
# designing algorithms, think about ways to optimize them for efficiency. Consider the time complexity of your algorithm and look for ways to improve it.
#
# 👉 Document your code: When writing code for algorithms, document your code thoroughly. Comment on what the code is doing, why it's doing it, and how it's doing it.
#
# 👉 Practice, practice, practice: The more you practice implementing algorithms in Python, the better you'll become. Take on challenging problems and work to solve them using algorithms.
#
# 👉 Collaborate with others: Collaborate with other programmers to learn new techniques and best practices for algorithm development. Share your code and get feedback from others to improve your skills.
#
# 👉 Stay up-to-date: Stay up-to-date with the latest developments in algorithm design and implementation. Read books, articles, and blogs to keep your knowledge current.
#
# ###**Shortcomings**
#
# 🤖💡🐍 Algorithm Fundamentals in Python: Shortcomings
#
#
# 👎 There are also some potential shortcomings to consider when working with algorithms:
#
# 🤔 Not a one-size-fits-all solution: Algorithms are not a one-size-fits-all solution to every problem. Some problems may require more complex solutions or may not be solvable with algorithms.
#
# 😓 Steep learning curve: Learning to design and implement algorithms can be challenging and requires a solid foundation in computer science and mathematics.
#
# 🐛 Bugs and errors: Even the most well-designed algorithms can contain bugs and errors that can be difficult to detect and fix.
#
# 🔍 Optimization challenges: Optimizing algorithms for efficiency can be a challenging task, and small changes in the code can have a significant impact on performance.
#
# 🚀 Rapidly changing technology: The world of computer science is rapidly changing, and new algorithm design techniques and technologies are emerging all the time. Keeping up with these changes can be a challenge.
#
# 🤝 Collaboration challenges: Collaborating with other programmers can be difficult when working on algorithms, as different programming styles and approaches can clash.
#
# 🌐 Data bias: Algorithms are only as good as the data they are trained on, and biased data can lead to biased results and unfair outcomes.
#
# 🤖 Despite these potential shortcomings, understanding algorithm fundamentals in Python can be incredibly useful for solving problems efficiently and effectively. It's important to be aware of these potential challenges and work to mitigate them as much as possible.

# %% [markdown]
# # **➕ Enhance your Knowledge ➕**

# %% [markdown]
# ###**Mnemonic**
#
#
# 🕵️‍♀️🌐👥 Once upon a time, there was a company called Codicon that specialized in Algorithm fundamentals in Python. The company's mission was to teach people the importance of algorithms and how they can be used to solve problems efficiently.
#
# 👨‍💼 The CEO of Codicon, a brilliant computer scientist, had a passion for algorithms and wanted to share his knowledge with the world. He assembled a team of experienced developers and educators who shared his passion and vision.
#
# 💼 Codicon's team worked tirelessly to develop high-quality educational content, including videos, interactive activities, and tutorials, to make learning algorithm fundamentals in Python fun and accessible for everyone.
#
# 🧑‍🎓 Students from all over the world came to Codicon to learn about algorithms and how they could apply them to real-world problems. The students were impressed with the quality of the educational materials and the expertise of the Codicon team.
#
# 🤝 Codicon also partnered with businesses and organizations to help them implement efficient algorithms to streamline their operations and save time and money.
#
# 🏆 As a result of their hard work and dedication, Codicon became a leading company in algorithm education and implementation. Their reputation spread far and wide, and they continued to make a positive impact on the tech industry.
#
# 🎉 Codicon's success was a testament to the power of algorithms and their ability to solve problems in innovative ways. The company's legacy lives on, inspiring future generations to embrace the power of algorithms and use them to make the world a better place.

# %% [markdown]
# ##**Additional Reference Paper**
# https://www.simplilearn.com/tutorials/data-structure-tutorial/what-is-an-algorithm

# %% [markdown]
# ##**Additional Learning Material**

# %% [markdown]
# ### **Selection Sort**

# %% [markdown]
# Selection Sort is another simple sorting algorithm that works by repeatedly finding the minimum element from the unsorted part of an array and putting it at the beginning. 🎯
#
# 👥 It can be visualized as a group of people standing in a line and selecting the shortest person and moving them to the front of the line. Then, they repeat the process to find the next shortest person and move them to the front until the entire line is sorted. 👫
#
# ⏰ Selection Sort has a time complexity of O(n^2) in all cases scenarios, which makes it inefficient for large data sets.
#
# 🔍 The algorithm iterates through the array, and for each iteration, it finds the minimum element from the unsorted part of the array and swaps it with the first unsorted element. This continues until the entire array is sorted.

# %% [markdown]
# For example, consider the following array: [5, 3, 4, 1, 2]
#
# The first iteration finds the minimum element from the unsorted part of the array, which is 1. It swaps 1 with the first element, and the array becomes [1, 3, 4, 5, 2].
#
# The second iteration finds the minimum element from the remaining unsorted part of the array, which is 2. It swaps 2 with the second element, and the array becomes [1, 2, 4, 5, 3].
#
# The third iteration finds the minimum element from the remaining unsorted part of the array, which is 3. It swaps 3 with the third element, and the array becomes [1, 2, 3, 5, 4].
#
# The fourth iteration finds the minimum element from the remaining unsorted part of the array, which is 4. It swaps 4 with the fourth element, and the array becomes [1, 2, 3, 4, 5].
#
# The final iteration finds the minimum element from the remaining unsorted part of the array, which is 64. It swaps 64 with the fifth element, but as it is already the maximum element, no swap is made. The array is now sorted: [1, 2, 3, 4, 5].

# %% [markdown]
# ![selec.gif](data:image/gif;base64,...)

# %% [markdown]
# Here is the code implementation of this example:

# %%
# define a function selection_sort that takes an array as an input
def selection_sort(arr):
    # get the length of the array
    n = len(arr)

    # iterate through the array
    for i in range(n-1):
        # set the minimum index to the current index
        min_index = i

        # iterate through the remaining elements to find the minimum element
        for j in range(i+1, n):
            # if the current element is less than the minimum element, update the minimum index
            if arr[j] < arr[min_index]:
                min_index = j

        # swap the minimum element with the first unsorted element
        arr[i], arr[min_index] = arr[min_index], arr[i]

    # return the sorted array
    return arr

# define an array to be sorted
arr = [5, 3, 4, 1, 2]
print("Given array:", arr)

# call the selection_sort function and assign the sorted array to a new variable
sorted_arr = selection_sort(arr)

# print the sorted array
print("Sorted array is:", sorted_arr)
# Out:
# Given array: [5, 3, 4, 1, 2]
# Sorted array is: [1, 2, 3, 4, 5]

# %% [markdown]
# Selection sort 🎯 has a time complexity of O(n^2), meaning that its performance decreases as the size of the input list grows. However, selection sort has the advantage of being easy to understand and implement 👍, making it a good choice for small lists or as a building block 🔨 for more complex sorting algorithms.
#
# ---

# %% [markdown]
# ### **Merge Sort**

# %% [markdown]
# ![Merge_sort_animation2.gif](data:image/gif;base64,...)

# %% [markdown]
# Merge Sort is a divide-and-conquer algorithm that works by recursively dividing the input  into two halves, sorting the two halves independently, and then merging them together.
#
# 🎯 The main idea behind Merge Sort is to divide the array into smaller subarrays, sort those subarrays, and then merge them back together in the correct order.
#
# 👥 It can be visualized as a group of people who are sorting themselves into height order by dividing themselves into two equal groups, sorting each group, and then merging the two sorted groups back together.
#
# ⏰ Merge Sort has a time complexity of O(nlogn) in all cases scenarios, making it an efficient sorting algorithm for large data sets.
#
# 🔍 The algorithm works by repeatedly dividing the input array in half until each subarray has only one element. Then, it recursively merges adjacent pairs of subarrays by comparing the smallest element of each subarray and placing the smaller element into a new merged subarray. This process continues until there is only one sorted subarray remaining.

# %% [markdown]
# For example, consider the following array: [38, 27, 43, 3, 9, 82, 10]

# %% [markdown]
# The Merge Sort algorithm works as follows:
#
# 1. Divide the input array into two halves: [38, 27, 43, 3] and [9, 82, 10].
#
# 2. Recursively divide each subarray in half until each subarray has only one element: [38], [27], [43], [3], [9], [82], and [10].
#
# 3. Merge adjacent pairs of subarrays by comparing the smallest element of each subarray and placing the smaller element into a new merged subarray. The two subarrays [38] and [27] are merged into [27, 38].The two subarrays [43] and [3] are merged into [3, 43]. The two subarrays [9] and [82] are merged into [9, 82].The two subarrays [10] and [3, 43] are merged into [3, 10, 43].
#
# 4. Recursively merge adjacent pairs of subarrays until there is only one sorted subarray remaining: [27, 38, 3, 43] and [9, 10, 3, 43, 82].
# 5. Merge the two sorted subarrays into a single sorted array: [3, 9, 10, 27, 38, 43, 82].

# %% [markdown]
# Here's the implementation of this example:

# %%
def merge_sort(arr):
    # Check if the input array is only one element or empty, if so, return it
    if len(arr) <= 1:
        return arr

    # Divide the array into two halves
    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    # Recursively call merge_sort on each half
    left_half = merge_sort(left_half)
    right_half = merge_sort(right_half)

    # Merge the two sorted halves
    i = j = 0  # Initialize two counters for the left and right halves
    merged_arr = []  # Create an empty list to store the merged array
    while i < len(left_half) and j < len(right_half):
        # Compare the first element of each half and add the smaller one to the merged array
        if left_half[i] < right_half[j]:
            merged_arr.append(left_half[i])
            i += 1
        else:
            merged_arr.append(right_half[j])
            j += 1

    # Append any remaining elements from the left or right halves to the merged array
    merged_arr += left_half[i:]
    merged_arr += right_half[j:]

    return merged_arr

arr = [64, 25, 12, 22, 11]
sorted_arr = merge_sort(arr)
print("Sorted array is:", sorted_arr)
# Out:
# Sorted array is: [11, 12, 22, 25, 64]

# %% [markdown]
# ###**Insertion Sort**

# %% [markdown]
# Insertion Sort is another simple sorting algorithm that works by sorting an array one element at a time. It iterates through an array and, for each element, finds the appropriate position within the sorted part of the array and inserts it there. 🎯
#
# 🔍 The algorithm starts by assuming the first element of the array is already sorted. It then iterates through the remaining unsorted part of the array and for each element, it compares it to the sorted part of the array and inserts it in the correct position. This process repeats until the entire array is sorted.

# %% [markdown]
# ![76_sorting.gif](data:image/gif;base64,...)

# %% [markdown]
# For example, consider the following array: [64, 25, 12, 22, 11]
#
# The first element is assumed to be sorted, so the algorithm starts with the second element (25) and compares it to the first element (64). Since 25 is smaller, it is moved to the left and the array becomes [25, 64, 12, 22, 11].
#
# The algorithm then moves on to the next unsorted element (12) and compares it to the sorted elements in reverse order. It finds that 12 is smaller than 64, so it moves 64 to the third position and 12 to the second position.
#
# The array now looks like this: [25, 12, 64, 22, 11]
#
# The algorithm continues this process for each unsorted element, comparing it to the sorted elements in reverse order and inserting it into its correct position.
#
# At the end of the process, the array is completely sorted in ascending order: [11, 12, 22, 25, 64].

# %% [markdown]
# Here is the implementation for this example:

# %%
def insertion_sort(arr):
    n = len(arr)

    # Traverse through 1 to n
    for i in range(1, n):
        key = arr[i]  # Select the key value to be inserted at the correct position
        j = i - 1     # Set the previous element index

        # Move elements of arr[0..i-1], that are greater than key, to one position ahead of their current position
        while j >= 0 and key < arr[j]:
            arr[j+1] = arr[j]
            j -= 1

        arr[j+1] = key  # Insert the key value in its correct position

    return arr

arr = [64, 25, 12, 22, 11]
print("Given arrayL", arr)
sorted_arr = insertion_sort(arr)
print("Sorted array is:", sorted_arr)
# Out:
# Given arrayL [64, 25, 12, 22, 11]
# Sorted array is: [11, 12, 22, 25, 64]

# %% [markdown]
# ⏰ Insertion Sort has a time complexity of O(n^2)  but it can perform better than other algorithms like Selection Sort and Bubble Sort for small data sets.
#
# ---

# %% [markdown]
# ### **Quick Sort**

# %% [markdown]
# ![Quicksort.gif](data:image/gif;base64,...)

# %% [markdown]
# Quick sort is a commonly used sorting algorithm that works by dividing an array into smaller sub-arrays and sorting them recursively. It uses a divide-and-conquer approach to sort the elements, making it a fast and efficient algorithm for large datasets.
#
# 👥 It can be visualized as a group of people standing in a line and selecting a "pivot" person. Then, they divide the remaining people into two groups, those taller than the pivot and those shorter than the pivot. They repeat this process recursively for each group until the entire line is sorted. 👫

# %% [markdown]
# The steps involved in quick sort are as follows:
#
# 1. Choose a pivot element from the array.
#
# 2. Partition the array so that all elements smaller than the pivot are on its left, and all elements larger than the pivot are on its right.
#
# 3. Recursively apply the above two steps to the sub-arrays on the left and right of the pivot until the entire array is sorted.

# %% [markdown]
# Here's an implementation of quick sort in Python:

# %%
def quick_sort(arr):
    # Base case
    if len(arr) <= 1:
        return arr

    # Selecting the first element as pivot
    pivot = arr[0]

    # Initializing empty arrays to store elements
    # smaller than pivot and greater than pivot
    left = []
    right = []

    # Iterating over the elements in the array,
    # excluding the pivot
    for i in range(1, len(arr)):
        # If the element is smaller than pivot,
        # add it to the left array
        if arr[i] < pivot:
            left.append(arr[i])
        # Otherwise, add it to the right array
        else:
            right.append(arr[i])

    # Recursively sorting the left and right arrays,
    # and concatenating the sorted arrays with the pivot
    return quick_sort(left) + [pivot] + quick_sort(right)

# Testing the function
arr = [65, 33, 54, 1, 12]
print("Given array:", arr)
sorted_arr = quick_sort(arr)
print("Sorted array is:", sorted_arr)
# Out:
# Given array: [65, 33, 54, 1, 12]
# Sorted array is: [1, 12, 33, 54, 65]

# %% [markdown]
# In this example, the quick_sort function takes an array arr as input and recursively sorts it using the quick sort algorithm. The base case is when the length of the array is less than or equal to 1, in which case the array is returned as is. The first element of the array is chosen as the pivot, and the remaining elements are partitioned into two sub-lists (left and right) based on whether they are less than or greater than the pivot. The function then recursively sorts the left and right sub-lists and concatenates them with the pivot element in between to get the final sorted array.
#
# ---

# %% [markdown]
# ### **Binary Search**

# %% [markdown]
# 🔎 Binary search is a searching algorithm that works by dividing the search space in half at each step, using a process of elimination to find the target value. 💡 It's typically faster than linear search, especially for large data sets.

# %% [markdown]
# 🔍 Here's how it works:
#
# 1. Start by finding the middle element of the data set.
# 2. Compare the middle element with the target element being searched for.
# 3. If the target is found, return the index of the element.
# 4. If the target is less than the middle element, repeat steps 1-3 on the left half of the data set.
# 5. If the target is greater than the middle element, repeat steps 1-3 on the right half of the data set.
# 6. If the target is not found, return -1.

# %% [markdown]
# ![binary.gif](data:image/gif;base64,...)

# %% [markdown]
# Here is an example for Binary Search:

# %%
# This function implements binary search algorithm to find the index of the target element in a given list of data.
def binary_search(data, target):
    left = 0   # Initialize the left pointer to the first index of the list.
    right = len(data) - 1   # Initialize the right pointer to the last index of the list.
    while left <= right:   # Loop until left pointer becomes greater than right pointer.
        mid = (left + right) // 2   # Calculate the middle index of the current search space.
        if data[mid] == target:   # If the middle element is the target element, return its index.
            return mid
        elif data[mid] < target:   # If the middle element is smaller than the target element, update the left pointer to mid+1.
            left = mid + 1
        else:   # If the middle element is larger than the target element, update the right pointer to mid-1.
            right = mid - 1
    return -1   # Target element was not found in the list, so return -1.

# Get user input for the list of data and the target value
data = list(map(int, input("Enter the list of data, separated by spaces: ").split()))
target = int(input("Enter the target value: "))

# Call the binary search function with the list of data and the target value
index = binary_search(data, target)

# If the target value is found in the list of data, print a message with the index of the element
if index != -1:
    print(f"Target {target} found at index {index}")
# If the target value is not found in the list of data, print a message indicating it was not found
else:
    print(f"Target {target} not found in data")
# Out:
# Enter the list of data, separated by spaces:   1 2 3 4 5 6 7 8 9
# Enter the target value: 6
# Target 6 found at index 5

# %% [markdown]
# In this example, the binary_search function takes two arguments: data, which is the list of values to search (which must be sorted), and target, which is the value we are searching for. The function uses a while loop to repeatedly divide the search space in half, comparing the middle element with the target value and adjusting the indices accordingly until the target is found or the search space is empty.

# %% [markdown]
# 🔍 Binary search is a very efficient searching algorithm, with a time complexity of O(log n), where n is the size of the data set. 💨 This makes it much faster than linear search for large data sets. 😎 However, it requires ⚠ that the data set be sorted in order for the algorithm to work correctly. 🔍 If the data set is unsorted, binary search will not be effective and other searching algorithms may be more appropriate.
#
# ---

# %% [markdown]
# ### **Interpolation Search**

# %% [markdown]
# Interpolation search is a 🕵️‍♀️ searching algorithm that improves upon binary search by making use of the distribution  of values in the data set. It is used to search for a target value in a sorted array with uniformly distributed values.
#
# The basic idea 💡 of the algorithm is to use interpolation to determine an approximate position  of the target value in the array, and then use binary search to find the exact position.

# %% [markdown]
# It calculates the probable position of the 🎯  target value in the sorted array by using the formula:
#
# pos = low + ((target - arr[low]) * (high - low)) / (arr[high] - arr[low])
#
# where "low" is the starting index of the array, "high" is the ending index of the array, "target" is the value being searched, and "arr" is the sorted array.
#
# This formula calculates the position of the 🎯 target value in the array based on the assumption that the array has uniformly distributed values. If the values are not uniformly distributed, the performance of the algorithm can degrade.

# %% [markdown]
# This formula calculates the position of the target value in the array based on the assumption that the array has uniformly distributed values. If the values are not uniformly distributed, the performance of the algorithm can degrade.
#
# Once the approximate position of the target value is calculated, binary search is used to find the exact position of the target value. If the target value is found, its index is returned. If it is not found, -1 is returned.

# %% [markdown]
# ![intpo.png](data:image/png;base64,...)

# %% [markdown]
# Here's an example of how to use interpolation search with a Python list:

# %%
# This function implements Interpolation search algorithm to find the index of the target element in a given list of data.
def interpolation_search(data, target):
    # Set the initial search range
    low = 0
    high = len(data) - 1

    # Continue searching while the search range is valid and the target value might be in the range
    while low <= high and target >= data[low] and target <= data[high]:
        # Calculate the estimated position of the target element using interpolation
        pos = low + ((high - low) // (data[high] - data[low])) * (target - data[low])

        # Check if the estimated position contains the target element
        if data[pos] == target:
            # Return the index of the target element
            return pos
        elif data[pos] < target:
            # If the estimated position is less than the target, search the upper half of the range
            low = pos + 1
        else:
            # If the estimated position is greater than the target, search the lower half of the range
            high = pos - 1

    # If the target element is not found, return -1
    return -1

# Get user input for the list of data and the target value
data = list(map(int, input("Enter the list of data, separated by spaces: ").split()))
target = int(input("Enter the target value: "))

# Call the interpolation search function with the list of data and the target value
index = interpolation_search(data, target)

# If the target value is found in the list of data, print a message with the index of the element
if index != -1:
    print(f"Target {target} found at index {index}")
# If the target value is not found in the list of data, print a message indicating it was not found
else:
    print(f"Target {target} not found in data")
# Out:
# Enter the list of data, separated by spaces: 2 5 9 15 26 35 57 69 84
# Enter the target value: 35
# Target 35 found at index 5

# %% [markdown]
# In this example, we have a sorted list of numbers, and we want to search for the target value using interpolation search. The algorithm estimates the position of the target element based on the values at the ends of the list and the value of the target itself. It then checks the estimated position and updates the search range accordingly until it finds the target or determines that it doesn't exist.

# %% [markdown]
# The time complexity of interpolation search is O(log log n) on average, where n is the size of the array. This is faster than binary search, which has a time complexity of O(log n) in the worst case. However, the worst case time complexity of interpolation search can be O(n) if the values in the array are not uniformly distributed.
#
# ---

# %% [markdown]
# # **Try it Yourself 📃**
#
# Are you ready to put your coding skills to the test and gain practical knowledge? We have some exciting coding questions waiting for you to solve! 🚀
#
# Your task is to attempt the coding questions associated with this lesson. These challenges have been thoughtfully designed to reinforce your understanding of the concepts covered in the course. You can find them in your dashboard under this lesson.
#
# Don't be shy! Share your findings, experiences, and any insights you gained while tackling these coding questions on the AlmaBetter community platform. Engage in discussions, help each other out, and celebrate your victories together!
#
# Remember, coding is not just about learning theory; it's about applying that knowledge to solve real-world problems. So, dive in, experiment, and have fun while honing your coding skills!
# Let's learn, grow, and inspire each other as a vibrant community of passionate learners. Happy coding! 💻 😊

# %% [markdown]
# ## **Task 1:**

# %% [markdown]
# ###**Activity 1:**
# Imagine you have a list of animals with their corresponding weights in pounds. You want to arrange the animals in ascending order based on their weight, starting from the lightest animal to the heaviest animal. For example, if you have a list of animals with the following weights: 🐘 elephant (5000 lbs), 🦒 giraffe (2000 lbs), 🦓 zebra (1000 lbs), and 🐰 rabbit (5 lbs), you want to arrange them in the following order: 🐰 rabbit, 🦓 zebra, 🦒 giraffe, 🐘 elephant.
#
# Here's how you can use bubble sort to accomplish this task:
#
# Create a list of animals and their corresponding weights in pounds.
# Implement the bubble sort algorithm to sort the animals based on their weights.
# Create a new list with the original animals assigned to the sorted weights.

# %%
# Your code here
Animal_list=[("elephant",5000),("giraffe",2000),("zebra",1000),("rabbit",5)]
n=len(Animal_list)
for i in range(n):
  for j in range(0,n-i-1):
    if Animal_list[j][1]>Animal_list[j+1][1]:
      Animal_list[j],Animal_list[j+1]=Animal_list[j+1],Animal_list[j]
sorted_list=[animal[0] for animal in Animal_list]
print(sorted_list)
# Out:
# ['rabbit', 'zebra', 'giraffe', 'elephant']

# %% [markdown]
# ###**Activity 2:**
# 🛒 You can use bubble sort to sort a list of groceries based on their prices. Imagine you have a shopping list 📝 of groceries 🍎🥦🍞 in no particular order, and you want to arrange the groceries in ascending order ⬆️ based on their prices 💰, starting from the cheapest item to the most expensive item.
#
# Here's how you can use bubble sort to accomplish this task:
#
# 1️⃣ Use this given list of groceries and their prices. ('Eggs', 2.5), ('Milk', 3.0), ('Bread', 1.5), ('Apples', 0.75), ('Cheese', 5.0)
#
# 2️⃣ Implement the bubble sort algorithm to sort the groceries based on their prices.
#
# 3️⃣ Create a new list with the original groceries assigned to the sorted prices.

# %%
# Your code here
item=[('Eggs', 2.5), ('Milk', 3.0), ('Bread', 1.5), ('Apples', 0.75), ('Cheese', 5.0)]
n=len(item)
for i in range(n):
  for j in range(0,n-i-1):
    if item[j][1]>item[j+1][1]:
      item[j],item[j+1]=item[j+1],item[j]
sorted_item=[i[0] for i in item]
print(sorted_item)
# Out:
# ['Apples', 'Bread', 'Eggs', 'Milk', 'Cheese']

# %% [markdown]
# ###**Activity 3:**
# Imagine you have a bookshelf with a random assortment of books 📚 on it, and you're looking for a specific book with the title "The Great Gatsby" 🎩. You don't know where the book is located on the bookshelf 🤷‍♂️, so you'll need to search through each book 📖 until you find the one you're looking for.
#
# Here's how you can use linear search to accomplish this task:
#
# Create a list 📃 of books on the bookshelf 📚, including "The Great Gatsby" and other random books.
# Implement the linear search algorithm to search through the list of books for "The Great Gatsby" 🔍.
# Output the position of "The Great Gatsby" on the bookshelf 📚.

# %%
# Here is the list of books on the bookshelf, including "The Great Gatsby" and other random books
bookshelf = ["Pride and Prejudice", "To Kill a Mockingbird", "The Catcher in the Rye", "1984", "The Great Gatsby", "Brave New World", "Animal Farm"]
key="The Great Gatsby"

# %%
# Your code here
def ass_books(bookshelf,key):
  for i in range(0,len(bookshelf)):
    if bookshelf[i]==key:
      return i
  return -1


bookshelf = ["Pride and Prejudice", "To Kill a Mockingbird", "The Catcher in the Rye", "1984", "The Great Gatsby", "Brave New World", "Animal Farm"]
key="The Great Gatsby"
ass_books(bookshelf,key)
# Out:
# 4

# %% [markdown]
# ###**Activity 4:**
# 👫👬👭 You have a list of your friends' names, represented as strings. Write a program that uses linear search to find the friend with the shortest name.
#
# 📝 Create a list of your friends' names, e.g. : ["Alice", "Bob", "Charlie", "David", "Eve", "Frank"]
#
# 💻 Implement a linear_search function that takes a list of names as a parameter and returns the name with the shortest length.
#
# 🔍 Call the linear_search function with the list of friends' names as an argument.
#
# 📣 Output the name of the friend with the shortest name using a print statement.
#
# 👨‍💻 Happy coding!

# %%
# Your code here
friends=["Alice", "Bob", "Charlie", "David", "Eve", "Frank"]
def linear_search(friends):
  shortest_name=friends[0]
  for i in range(1,len(friends)):
    if len(friends[i])<len(shortest_name):
      shortest_name=friends[i]
  return shortest_name


linear_search(friends)
# Out:
# 'Bob'

# %% [markdown]
# ###**Activity 5:**
# Imagine you have a list of candies with their corresponding sugar content in grams. You want to arrange the candies in descending order based on their sugar content, starting from the candy with the most sugar to the candy with the least sugar. For example, if you have a list of candies with the following sugar content: 🍭 lollipop (30 g), 🍬 gumdrop (20 g), 🍫 chocolate (15 g), and 🍮 jelly bean (10 g), you want to arrange them in the following order: 🍭 lollipop, 🍬 gumdrop, 🍫 chocolate, 🍮 jelly bean.
#
# Here's how you can use merge sort to accomplish this task:
#
# Create a list of candies and their corresponding sugar content in grams.
#
# Implement the merge sort algorithm to sort the candies based on their sugar content.
#
# Create a new list with the original candies assigned to the sorted sugar content.

# %%
# Your code here

# %% [markdown]
# ## **Task 2:**

# %% [markdown]
# ####**🔵 Share your thoughts and findings about the importance of learning Data Structures in the AlmaBetter Community Platform.**
